# %% [markdown]
# # Imports

# %%
import pandas                 as pd
import numpy                  as np
import seaborn                as sns
import matplotlib.pyplot      as plt
import scikitplot             as skplt
import sklearn
import inflection

from sklearn.preprocessing    import MinMaxScaler, StandardScaler
from sklearn                  import model_selection
from sklearn.model_selection  import StratifiedKFold
from sklearn                  import ensemble
from sklearn                  import neighbors
from sklearn                  import linear_model
from sklearn.metrics          import roc_auc_score
from sklearn.ensemble         import RandomForestClassifier
from sklearn.naive_bayes      import GaussianNB
from xgboost                  import XGBClassifier
from lightgbm                 import LGBMClassifier
from catboost                 import CatBoostClassifier
from kds.metrics              import plot_cumulative_gain, plot_lift

from IPython.display          import Image
from IPython.core.display     import HTML

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# ### Models Performance

# %%
# definition of precision_at_k for the top 20.000 clients as default
def precision_at_k (data, k=2000):
    
    # reset index
    data = data.reset_index(drop=True)
    
    #create ranking order
    data['ranking'] = data.index + 1
    
    #calculate precision based on column named response
    data['precision_at_k'] = data['response'].cumsum() / data['ranking']
    
    return data.loc[k, 'precision_at_k']

# definition of recall_at_k for the top 20.000 clients as default
def recall_at_k (data, k=20000):
    
    # reset index
    data = data.reset_index(drop=True)
    
    #create ranking order
    data['ranking'] = data.index + 1
    
    #calculate recall based on the sum of responses
    data['recall_at_k'] = data['response'].cumsum() / data['response'].sum()
    
    return data.loc[k, 'recall_at_k']

##Define models accuracy function
def accuracy (model, x_val, y_val, yhat):
    
    data = x_val.copy()
    data['response'] = y_val.copy()
    data['score'] = yhat[:, 1].tolist()
    data = data.sort_values('score', ascending=False)
   
    precision = precision_at_k(data)      
    recall = recall_at_k(data)
    f1_score = round(2*(precision * recall) / (precision + recall), 3)
    roc = roc_auc_score(y_val, yhat[:,1])
    
    return pd.DataFrame({'Model Name': type(model).__name__,
                         'ROC AUC': roc.round(4),
                         'Precision@K Mean': np.mean(precision).round(4),
                         'Recall@K Mean': np.mean(recall).round(4),
                         'F1_Score' : np.mean(f1_score).round(4)}, index=[0])

## Define Cross-Validation
def cross_validation(model, x_train, y_train, k, data, Verbose = True):
    
    kfold = StratifiedKFold(n_splits=k, shuffle=True, random_state=28)
    precision_list = []
    recall_list = []
    f1_score_list = []
    roc_list = []
    i=1

    for train_cv, val_cv in kfold.split(x_train, y_train):
        
        if Verbose == True:
            
            print(f'Fold Number {i}/{k}')
            
        else:
            pass
        
        x_train_fold = x_train.iloc[train_cv]
        y_train_fold = y_train.iloc[train_cv]
        x_val_fold = x_train.iloc[val_cv]
        y_val_fold = y_train.iloc[val_cv]

        model_fit = model.fit(x_train_fold, y_train_fold.values.ravel())
        yhat = model.predict_proba(x_val_fold)        
        
        data = x_val_fold.copy()
        data['response'] = y_val_fold.copy()
        data['score'] = yhat[:, 1].tolist()
        data = data.sort_values('score', ascending=False)

        precision = precision_at_k(data) 
        precision_list.append(precision)
        
        recall = recall_at_k(data)
        recall_list.append(recall)
        
        f1_score = round(2*(precision * recall) / (precision + recall), 3)
        f1_score_list.append(f1_score)
       
        roc = roc_auc_score(y_val_fold, yhat[:, 1])
        roc_list.append(roc)
            
        
        i+=1
        
    df = pd.DataFrame({'Model Name': type(model).__name__,
                         'ROC AUC': roc.round(4),
                         'Precision@K Mean': np.mean(precision).round(4),
                         'Recall@K Mean': np.mean(recall).round(4),
                         'F1_Score' : np.mean(f1_score).round(4)}, index=[0])
    return df
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# ### Graphic

# %%
def jupyter_settings():
    # %matplotlib inline
    # %pylab inline
    
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    plt.rcParams['font.size'] = 24
    
    display( HTML( '<style>.container { width:100% !important; }</style>') )
    pd.options.display.max_columns = None
    pd.options.display.max_rows = None
    pd.set_option( 'display.expand_frame_repr', False )
    
    sns.set()

jupyter_settings();

# %% [markdown]
# ## Loading Data

# %%
df_raw = pd.read_csv('data/train.csv')

# %% [markdown]
# # Data Details

# %%
df2 = df_raw.copy()

# %%
df2.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response
# 0   1    Male   44                1         28.0                   0   > 2 Years            Yes         40454.0                  26.0      217         1
# 1   2    Male   76                1          3.0                   0    1-2 Year             No         33536.0                  26.0      183         0
# 2   3    Male   47                1         28.0                   0   > 2 Years            Yes         38294.0                  26.0       27         1
# 3   4    Male   21                1         11.0                   1    < 1 Year             No         28619.0                 152.0      203         0
# 4   5  Female   29                1         41.0                   1    < 1 Year             No         27496.0                 152.0       39         0

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# |The data set that we're using is from Kaggle (https://www.kaggle.com/anmolkumar/health-insurance-cross-sell-prediction).
#
#
#
# | Feature                                       |Description
# |:---------------------------|:---------------
# | **Id**                         | Unique ID for the customer   |
# | **Gender**                           | Gender of the customer   |
# | **Age**                           | Age of the customer   |
# | **Driving License**                                   | 0, customer does not have DL; 1, customer already has DL  |
# | **Region Code**                               | Unique code for the region of the customer   |
# | **Previously Insured**                     | 1, customer already has vehicle insurance; 0, customer doesn't have vehicle insurance |
# | **Vehicle Age**                     | Age of the vehicle |
# | **Vehicle Damage**                                  | 1, customer got his/her vehicle damaged in the past; 0, customer didn't get his/her vehicle damaged in the past |
# | **Anual Premium**                             | The amount customer needs to pay as premium in the year |
# | **Policy sales channel**                                    | Anonymized Code for the channel of outreaching to the customer ie  |
# | **Vintage**                | Number of Days, customer has been associated with the company  |
# | **Response**              | 1, customer is interested; 0, customer is not interested. |

# %% [markdown]
# ## Rename Columns

# %%
cols_old = ['id', 'Gender', 'Age', 'Driving_License', 'Region_Code', 'Previously_Insured', 'Vehicle_Age', 'Vehicle_Damage', 'Annual_Premium', 
            'Policy_Sales_Channel', 'Vintage', 'Response']

snakecase = lambda x: inflection.underscore( x )

cols_new = list( map( snakecase, cols_old ) )

# rename
df2.columns = cols_new

# %% [markdown]
# ## Data Dimensions

# %%
print ('Number of Rows: {}'.format( df2.shape[0]))
print ('Number of Columns: {}'.format( df2.shape[1]))
# Out:
# Number of Rows: 381109
# Number of Columns: 12

# %% [markdown]
# ## Data Types

# %%
df2.dtypes
# Out:
# id                        int64
# gender                   object
# age                       int64
# driving_license           int64
# region_code             float64
# previously_insured        int64
# vehicle_age              object
# vehicle_damage           object
# annual_premium          float64
# policy_sales_channel    float64
# vintage                   int64
# response                  int64
# dtype: object

# %% [markdown]
# ## Missing Values

# %%
df2.isna().sum()
# Out:
# id                      0
# gender                  0
# age                     0
# driving_license         0
# region_code             0
# previously_insured      0
# vehicle_age             0
# vehicle_damage          0
# annual_premium          0
# policy_sales_channel    0
# vintage                 0
# response                0
# dtype: int64

# %% [markdown]
# ## Change Types

# %%
# changing data types from float to int64

df2['region_code'] = df2['region_code'].astype('int64')     

df2['policy_sales_channel'] = df2['policy_sales_channel'].astype('int64')    

df2['annual_premium'] = df2['annual_premium'].astype('int64')

# %% [markdown]
# ## Descriptive Statistics

# %%
# Split numerical and categorical features
num_attributes = df2.select_dtypes( include=['int64', 'float64'])
cat_attributes = df2.select_dtypes( exclude=['int64', 'float64'])

# %% [markdown]
# ### Numerical Attributes

# %%
#Central Tendency - mean, meadian
ct1 = pd.DataFrame( num_attributes.apply( np.mean ) ).T
ct2 = pd.DataFrame( num_attributes.apply( np.median ) ).T

# dispersion - std, min, max, range, skew, kurtosis
d1 = pd.DataFrame( num_attributes.apply( np.std ) ).T
d2 = pd.DataFrame( num_attributes.apply( min ) ).T
d3 = pd.DataFrame( num_attributes.apply( max ) ).T
d4 = pd.DataFrame( num_attributes.apply( lambda x: x.max() - x.min() ) ).T
d5 = pd.DataFrame( num_attributes.apply( lambda x: x.skew() ) ).T
d6 = pd.DataFrame( num_attributes.apply( lambda x: x.kurtosis() ) ).T

# concat
m= pd.concat( [d2, d3, d4, ct1, ct2, d1, d5, d6] ).T.reset_index()
m.columns = ['attributes','min', 'max', 'range', 'mean', 'median', 'std', 'skew', 'kurtosis']
m
# Out:
#              attributes     min       max     range           mean    median            std          skew    kurtosis
# 0                    id     1.0  381109.0  381108.0  190555.000000  190555.0  110016.691870  9.443274e-16   -1.200000
# 1                   age    20.0      85.0      65.0      38.822584      36.0      15.511591  6.725390e-01   -0.565655
# 2       driving_license     0.0       1.0       1.0       0.997869       1.0       0.046109 -2.159518e+01  464.354302
# 3           region_code     0.0      52.0      52.0      26.388807      28.0      13.229871 -1.152664e-01   -0.867857
# 4    previously_insured     0.0       1.0       1.0       0.458210       0.0       0.498251  1.677471e-01   -1.971871
# 5        annual_premium  2630.0  540165.0  537535.0   30564.389581   31669.0   17213.132474  1.766087e+00   34.004569
# 6  policy_sales_channel     1.0     163.0     162.0     112.034295     133.0      54.203924 -9.000081e-01   -0.970810
# 7               vintage    10.0     299.0     289.0     154.347397     154.0      83.671194  3.029517e-03   -1.200688
# 8              response     0.0       1.0       1.0       0.122563       0.0       0.327935  2.301906e+00    3.298788

# %% [markdown]
# **Age** of customers ranges from 20 to 85 years old, average being close to 38.
#
# **Driving Licence** ≈ 100% of the clients in analysis retain a one
#
# **Vehicle insurance** ≈ 55% of the clients do not hold one
#
# **Annual Premium** Clients pay ≈ 30.5k on their current health insurance policy
#
# **Response** 12.23% of the clients showed to be interest in purchasing a vehicle insurance.

# %% [markdown]
# ### Categorical Attributes

# %%
# add percentage of most common attribute
cat_attributes_p = cat_attributes.describe().T
cat_attributes_p['freq_p'] = cat_attributes_p['freq'] / cat_attributes_p['count']
cat_attributes_p
# Out:
#                  count unique       top    freq    freq_p
# gender          381109      2      Male  206089  0.540761
# vehicle_age     381109      3  1-2 Year  200316  0.525613
# vehicle_damage  381109      2       Yes  192413  0.504877

# %% [markdown]
# **Gender** ≈ 54% of the customers are Male
#
# **Vehicle Age** Customers age vehicle is most commonly between 1 and 2 years old
#
# **Vehicle Damage** ≈ 50% of the customers got his/her vehicle damaged in the past

# %% [markdown]
# **TOP 3 Combos Categorical Attributes**

# %%
categorical_combo = pd.DataFrame(round(cat_attributes.value_counts(normalize=True) * 100)).reset_index().rename(columns={0: '%'})
categorical_combo['count'] = cat_attributes.value_counts().values
display(categorical_combo)
# Out:
#     gender vehicle_age vehicle_damage     %  count
# 0     Male    1-2 Year            Yes  21.0  79533
# 1   Female    < 1 Year             No  17.0  66047
# 2     Male    < 1 Year             No  13.0  50543
# 3   Female    1-2 Year            Yes  13.0  48692
# 4     Male    1-2 Year             No  11.0  42791
# 5   Female    1-2 Year             No   8.0  29300
# 6   Female    < 1 Year            Yes   7.0  25274
# 7     Male    < 1 Year            Yes   6.0  22922
# 8     Male   > 2 Years            Yes   3.0  10293
# 9   Female   > 2 Years            Yes   1.0   5699
# 10  Female   > 2 Years             No   0.0      8
# 11    Male   > 2 Years             No   0.0      7

# %% [markdown]
# **1.** Males with car age between 1-2 years old that got vehicle damaged in the past
#
# **2.** Female with car newer than 1 year old that never got vehicle damage in the past
#
# **3.** Males with car newer than 1 year old that never got vehicle damage in the past

# %% [markdown]
# # Feature Engineering

# %%
df3 = df2.copy()

# %% [markdown]
# ## Features Creation

# %%
# vehicle age
df3['vehicle_age']= df3['vehicle_age'].apply( lambda x: 'over_2_years' if x == '> 2 Years' else 'between_1_2year' if x== '1-2 Year' else 'between_1_2_year')
# vehicle damage
df3['vehicle_damage'] = df3['vehicle_damage'].apply( lambda x: 1 if x == 'Yes' else 0 )

# %% [markdown]
# ## Mind Map

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
df4 = df3.copy()

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Response Variable

# %%
sns.countplot(x = 'response', data=df4);

# %% [markdown]
# ### Numerical Variables

# %%
num_attributes.hist(bins=25);

# %% [markdown]
# #### Age
#
# **Findings** The average age of interested clients is higher than non-interested clients. Both plots disclose well how younger clients are not as interested as older clients.

# %%
plt.subplot(1, 2, 1)
sns.boxplot( x='response', y='age', data=df4 )

plt.subplot(1, 2, 2)
sns.histplot(df4, x='age', hue='response');

# %% [markdown]
# #### Driving Licence
# **Findings** Only clients holding a driving license are part of the dataset. 12% are potential vehicle insurance customers

# %%
aux2 = pd.DataFrame(round(df4[['driving_license', 'response']].value_counts(normalize=True) * 100)).reset_index().rename(columns={0: '%'})
aux2['count'] = (aux2['%'] * df4.shape[0]).astype(int)
aux2
# Out:
#    driving_license  response     %     count
# 0                1         0  88.0  33537592
# 1                1         1  12.0   4573308
# 2                0         0   0.0         0
# 3                0         1   0.0         0

# %%
aux2 = df4[['driving_license', 'response']].groupby( 'response' ).sum().reset_index()
sns.barplot( x='response', y='driving_license', data=aux2 );

# %% [markdown]
# #### Region Code

# %%
aux3 = df4[['id', 'region_code', 'response']].groupby( ['region_code', 'response'] ).count().reset_index()
aux3 = aux3[(aux3['id'] > 1000) & (aux3['id'] < 20000)]
sns.scatterplot( x='region_code', y='id', hue='response', data=aux3 );

# %% [markdown]
# #### Previously Insured
# **Findings** All potential vehicle insurance customers have never held an insurance. 46% of our clients already have vehicle insurance and are not interested.

# %%
aux4 = pd.DataFrame(round(df4[['previously_insured', 'response']].value_counts(normalize=True) * 100)).reset_index().rename(columns={0: '%'})
aux4['count'] = (aux4['%'] * df4.shape[0]).astype(int)
aux4
# Out:
#    previously_insured  response     %     count
# 0                   1         0  46.0  17531014
# 1                   0         0  42.0  16006578
# 2                   0         1  12.0   4573308
# 3                   1         1   0.0         0

# %%
sns.barplot(data=aux4, x='previously_insured', y='count', hue='response');

# %% [markdown]
# #### Annual Premium
# **Findings** Annual premiums for both interested and non-interested clients are very similar.

# %%
aux5 = df4[(df4['annual_premium'] <100000)]
sns.boxplot( x='response', y='annual_premium', data=aux5 );

# %% [markdown]
# #### Policy Sales Channel
# **Findings**

# %%
aux6 = df4[['policy_sales_channel', 'response']].groupby( 'policy_sales_channel' ).sum().reset_index()

plt.xticks(rotation=90)
ax6 = sns.barplot( x='response', y='policy_sales_channel', data=aux6, order = aux6['response']);

# %%
aux6 = df4[['policy_sales_channel', 'response']].groupby( 'policy_sales_channel' ).sum().reset_index()

plt.xticks(rotation=90)
ax6 = sns.barplot( x='response', y='policy_sales_channel', data=aux6, order = aux6['response']);

# %% [markdown]
# #### Vintage
# **Findings**

# %%
plt.subplot(1, 2, 1)
sns.boxplot( x='response', y='vintage', data=df4 )

plt.subplot(1, 2, 2)
sns.histplot(df4, x='vintage', hue='response');

# %% [markdown]
# ### Categorical Variables

# %% [markdown]
# #### Gender

# %%
aux7 = pd.DataFrame(round(df4[['gender', 'response']].value_counts(normalize=True) * 100)).reset_index().rename(columns={0: '%'})
aux7['count'] = (aux7['%'] * df4.shape[0]).astype(int)
aux7
# Out:
#    gender  response     %     count
# 0    Male         0  47.0  17912123
# 1  Female         0  41.0  15625469
# 2    Male         1   7.0   2667763
# 3  Female         1   5.0   1905545

# %%
sns.barplot(data=aux7, x='gender', y='count', hue='response');

# %% [markdown]
# #### Vehicle Age

# %%
aux8 = pd.DataFrame(round(df4[['vehicle_age', 'response']].value_counts(normalize=True) * 100)).reset_index().rename(columns={0: '%'})
aux8['count'] = (aux8['%'] * df4.shape[0]).astype(int)
aux8
# Out:
#         vehicle_age  response     %     count
# 0   between_1_2year         0  43.0  16387687
# 1  between_1_2_year         0  41.0  15625469
# 2   between_1_2year         1   9.0   3429981
# 3      over_2_years         0   3.0   1143327
# 4  between_1_2_year         1   2.0    762218
# 5      over_2_years         1   1.0    381109

# %%
sns.barplot(data=aux8, x='vehicle_age', y='count', hue='response');

# %% [markdown]
# #### Vehicle Damage

# %%
aux9 = pd.DataFrame(round(df4[['vehicle_damage', 'response']].value_counts(normalize=True) * 100)).reset_index().rename(columns={0: '%'})
aux9['count'] = (aux9['%'] * df4.shape[0]).astype(int)
aux9
# Out:
#    vehicle_damage  response     %     count
# 0               0         0  49.0  18674341
# 1               1         0  38.0  14482142
# 2               1         1  12.0   4573308
# 3               0         1   0.0         0

# %%
sns.barplot(data=aux9, x='vehicle_damage', y='count', hue='response');

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### Numerical Attributed
# **Finding** Having the target variable in scope, the stronger correlations with feature 'Previously Insured' (-0.34), 'Policy Sales Channel' (-0.14) and 'Age' (0.11). Outside the target variable scope, between Age and Policy Sales Chanel there is strong negative correlation of -0.58), 'Previously Insured' and 'Age' of -0.25 and last between 'Previously Insured' and 'Policy Sales Channel' 0.22.

# %%
corr_matrix= num_attributes.corr()
# Half matrix
mask = np.zeros_like(corr_matrix)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr_matrix, mask = mask, annot = True, square = True, cmap='YlGnBu');

# %% [markdown]
# # Data Preparation

# %%
df5 = df4.copy()

# %% [markdown]
# ## Standardization of DataSets

# %%
df5['annual_premium'] = StandardScaler().fit_transform( df5[['annual_premium']].values)

# %% [markdown]
# ## Rescaling

# %%
mms = MinMaxScaler()

#age
df5['age'] = mms.fit_transform( df5[['age']].values)

#vintage
df5['vintage'] = mms.fit_transform( df5[['vintage']].values)

# %% [markdown]
# ## Transformation

# %% [markdown]
# ### Encoding

# %%
#gender - target encoder
target_encode_gender = df5.groupby('gender')['response'].mean()
df5.loc[:, 'gender'] = df5['gender'].map(target_encode_gender)

# region_code - Target Encoding - as there are plenty of categories (as seen in EDA) it is better not to use one hot encoding and to use 
target_encode_region_code = df5.groupby('region_code')['response'].mean()
df5.loc[:, 'region_code'] = df5['region_code'].map(target_encode_region_code)

#vehicle_age
df5 = pd.get_dummies( df5, prefix='vehicle_age', columns=['vehicle_age'] )

#policy_sales_channel - Frequency encode
fe_policy_sales_channel = df5.groupby('policy_sales_channel').size()/len( df5)
df5['policy_sales_channel'] = df5['policy_sales_channel'].map(fe_policy_sales_channel)

# %% [markdown]
# # Feature Selection

# %%
df6 = df5.copy()

# %% [markdown]
# ## Split dataframe into training and test

# %%
X = df6.drop('response', axis=1)
y = df6['response'].copy()

x_train, x_val, y_train, y_val = model_selection.train_test_split(X, y, test_size = 0.2)

df6 = pd.concat ( [x_train, y_train], axis = 1)

# %% [markdown]
# ## Feature Importance

# %%
forest = ensemble.ExtraTreesClassifier( n_estimators = 250, random_state = 42, n_jobs = -1)

x_train_n = df6.drop(['id', 'response'], axis=1 )
y_train_n = y_train.values
forest.fit( x_train_n, y_train_n)
# Out:
# ExtraTreesClassifier(n_estimators=250, n_jobs=-1, random_state=42)

# %%
importances = forest.feature_importances_
std = np.std([tree.feature_importances_ for tree in forest.estimators_], axis = 0)
indices = np.argsort(importances)[::-1]
#print the feature ranking
print( "Feature Rankings")
df = pd.DataFrame()
for i, j in zip(x_train_n, forest.feature_importances_):
    aux = pd.DataFrame( {'feature': i, 'importance':j}, index=[0])
    df = pd.concat ([df, aux], axis = 0)
    
print( df.sort_values( 'importance', ascending=False))

# PLt the impurity-based feature importance of the features
plt.figure()
plt.title('Feature Importance')
plt.bar(range(x_train_n.shape[1]), importances[indices], color="r", yerr=std[indices], align="center")
plt.xticks(range(x_train_n.shape[1]), indices)
plt.xlim([-1, x_train_n.shape[1]])
plt.show()
# Out:
# Feature Rankings
#                         feature  importance
# 0                       vintage    0.273248
# 0                annual_premium    0.245423
# 0                           age    0.164214
# 0                   region_code    0.104047
# 0                vehicle_damage    0.071701
# 0          policy_sales_channel    0.062706
# 0            previously_insured    0.052021
# 0  vehicle_age_between_1_2_year    0.012235
# 0   vehicle_age_between_1_2year    0.006022
# 0                        gender    0.005080
# 0      vehicle_age_over_2_years    0.002817
# 0               driving_license    0.000488

# %% [markdown]
# # Machine Learning Modelling

# %%
#I will use as well 'driving_license' as it seemes an importante feature in EDA
cols_selected = ['vintage', 'annual_premium', 'age', 'region_code', 
                 'vehicle_damage', 'policy_sales_channel', 'driving_license']

cols_not_selected = ['previously_insured', 'vehicle_age_between_1_2_year', 'vehicle_age_between_1_2year', 'gender', 'vehicle_age_over_2_years']

#create df to be used for business understading
x_validation = x_val.drop(cols_not_selected, axis=1)

#create dfs for modeling
x_train = df6[cols_selected]
x_val = x_val[cols_selected]

# %% [markdown]
# ## Logistic Regression

# %% [markdown]
# ### Model Building

# %%
#define model
lr = linear_model.LogisticRegression (random_state = 42)

#train model
lr.fit( x_train, y_train)

#model prediction
yhat_lr = lr.predict_proba( x_val)

# %% [markdown]
# ### Model Single Performance

# %%
accuracy_lr = accuracy(lr, x_val, y_val, yhat_lr)
accuracy_lr
# Out:
#            Model Name   ROC AUC  Precision@K Mean  Recall@K Mean  F1_Score
# 0  LogisticRegression  0.802364          0.264868       0.581653     0.364

# %% [markdown]
# ### Cross Validation Performance

# %%
accuracy_cv_lr = cross_validation(lr, x_train, y_train, 5, df6, Verbose = True)
accuracy_cv_lr
# Out:
# Fold Number 1/5
# Fold Number 2/5
# Fold Number 3/5
# Fold Number 4/5
# Fold Number 5/5
#            Model Name   ROC AUC  Precision@K Mean  Recall@K Mean  F1_Score
# 0  LogisticRegression  0.803912          0.277361       0.719392       0.4

# %% [markdown]
# ### Performance Plotted

# %%
# Accumulative Gain
skplt.metrics.plot_cumulative_gain(y_val, yhat_lr, figsize = (10, 5));

# %%
# Lift Curve
skplt.metrics.plot_lift_curve( y_val, yhat_lr, figsize = (10, 5) );

# %% [markdown]
# ## Naive Bayes

# %% [markdown]
# ### Model Building

# %%
#define model
naive = GaussianNB()

#train model
naive.fit( x_train, y_train)

#model prediction
yhat_naive = naive.predict_proba( x_val)

# %% [markdown]
# ### Model Single Performance

# %%
accuracy_naive = accuracy(naive, x_val, y_val, yhat_naive)
accuracy_naive
# Out:
#    Model Name   ROC AUC  Precision@K Mean  Recall@K Mean  F1_Score
# 0  GaussianNB  0.811845          0.270865       0.609087     0.375

# %% [markdown]
# ### Cross Validation Performance

# %%
accuracy_cv_naive = cross_validation(naive, x_train, y_train, 5, df6, Verbose = True)
accuracy_cv_naive
# Out:
# Fold Number 1/5
# Fold Number 2/5
# Fold Number 3/5
# Fold Number 4/5
# Fold Number 5/5
#    Model Name  ROC AUC  Precision@K Mean  Recall@K Mean  F1_Score
# 0  GaussianNB   0.8131          0.283858       0.753668     0.412

# %% [markdown]
# ### Performance Plotted

# %%
# Accumulative Gain
skplt.metrics.plot_cumulative_gain(y_val, yhat_naive, figsize = (10, 5));

# %%
# Lift Curve
skplt.metrics.plot_lift_curve( y_val, yhat_naive, figsize = (10, 5) );

# %% [markdown]
# ## Extra Trees

# %% [markdown]
# ### Model Building

# %%
#define model
et = ensemble.ExtraTreesClassifier (random_state = 42, n_jobs=-1)

#train model
et.fit( x_train, y_train)

#model prediction
yhat_et = et.predict_proba( x_val)

# %% [markdown]
# ### Model Single Performance

# %%
accuracy_et = accuracy(et, x_val, y_val, yhat_et)
accuracy_et
# Out:
#              Model Name   ROC AUC  Precision@K Mean  Recall@K Mean  F1_Score
# 0  ExtraTreesClassifier  0.809104          0.331834       0.621991     0.433

# %% [markdown]
# ### Cross Validation Performance

# %%
accuracy_cv_et = cross_validation(et, x_train, y_train, 5, df6, Verbose = True)
accuracy_cv_et
# Out:
# Fold Number 1/5
# Fold Number 2/5
# Fold Number 3/5
# Fold Number 4/5
# Fold Number 5/5
#              Model Name   ROC AUC  Precision@K Mean  Recall@K Mean  F1_Score
# 0  ExtraTreesClassifier  0.811396          0.329835       0.748733     0.458

# %% [markdown]
# ### Performance Plotted

# %%
# Accumulative Gain
skplt.metrics.plot_cumulative_gain(y_val, yhat_et, figsize = (10, 5));

# %%
# Lift Curve
skplt.metrics.plot_lift_curve( y_val, yhat_et, figsize = (10, 5) );

# %% [markdown]
# ## Random Forest Regressor

# %% [markdown]
# ### Model Building

# %%
#define model
rf=RandomForestClassifier(n_estimators=100, min_samples_leaf=25)

#train model
rf.fit( x_train, y_train)

#model prediction
yhat_rf = rf.predict_proba( x_val)

# %% [markdown]
# ### Model Single Performance

# %%
accuracy_rf = accuracy(rf, x_val, y_val, yhat_rf)
accuracy_rf
# Out:
#                Model Name   ROC AUC  Precision@K Mean  Recall@K Mean  F1_Score
# 0  RandomForestClassifier  0.842642          0.398301       0.687486     0.504

# %% [markdown]
# ### Cross Validation Performance

# %%
accuracy_cv_rf = cross_validation(rf, x_train, y_train, 5, df6, Verbose = True)
accuracy_cv_rf
# Out:
# Fold Number 1/5
# Fold Number 2/5
# Fold Number 3/5
# Fold Number 4/5
# Fold Number 5/5
#                Model Name   ROC AUC  Precision@K Mean  Recall@K Mean  F1_Score
# 0  RandomForestClassifier  0.841617          0.398801       0.805815     0.534

# %% [markdown]
# ### Performance Plotted

# %%
# Accumulative Gain
skplt.metrics.plot_cumulative_gain(y_val, yhat_rf, figsize = (10, 5));

# %%
# Lift Curve
skplt.metrics.plot_lift_curve( y_val, yhat_rf, figsize = (10, 5) );

# %% [markdown]
# ## KNN Classifier

# %% [markdown]
# ### Model Building

# %%
#define model
knn = neighbors.KNeighborsClassifier (n_neighbors = 8)

#train model
knn.fit( x_train, y_train)

#model prediction
yhat_knn = knn.predict_proba( x_val)

# %% [markdown]
# ### Model Single Performance

# %%
accuracy_knn = accuracy(knn, x_val, y_val, yhat_knn)
accuracy_knn
# Out:
#              Model Name   ROC AUC  Precision@K Mean  Recall@K Mean  F1_Score
# 0  KNeighborsClassifier  0.779595           0.31934       0.619172     0.421

# %% [markdown]
# ### Cross Validation Performance

# %%
accuracy_cv_knn = cross_validation(knn, x_train, y_train, 5, df6, Verbose = True)
accuracy_cv_knn
# Out:
# Fold Number 1/5
# Fold Number 2/5
# Fold Number 3/5
# Fold Number 4/5
# Fold Number 5/5
#              Model Name   ROC AUC  Precision@K Mean  Recall@K Mean  F1_Score
# 0  KNeighborsClassifier  0.779613          0.335832        0.72646     0.459

# %% [markdown]
# ### Performance Plotted

# %%
# Accumulative Gain
skplt.metrics.plot_cumulative_gain(y_val, yhat_knn, figsize = (10, 5));

# %%
# Lift Curve
skplt.metrics.plot_lift_curve( y_val, yhat_knn, figsize = (10, 5) );

# %% [markdown]
# ### Cross Validation

# %% [markdown]
# ## XGBoost Classifier

# %% [markdown]
# ### Model Building

# %%
#define model
xgboost = XGBClassifier(objective='binary:logistic',
                        eval_metric='error',
                        n_estimators = 100,
                        random_state = 22)

#train model
xgboost.fit( x_train, y_train)

#model prediction
yhat_xgboost = xgboost.predict_proba( x_val)

# %% [markdown]
# ### Model Single Performance

# %%
accuracy_xgboost = accuracy(xgboost, x_val, y_val, yhat_xgboost)
accuracy_xgboost
# Out:
#       Model Name   ROC AUC  Precision@K Mean  Recall@K Mean  F1_Score
# 0  XGBClassifier  0.844104          0.407296       0.691824     0.513

# %% [markdown]
# ### Cross Validation Performance

# %%
accuracy_cv_xgboost = cross_validation(xgboost, x_train, y_train, 5, df6, Verbose = True)
accuracy_cv_xgboost
# Out:
# Fold Number 1/5
# Fold Number 2/5
# Fold Number 3/5
# Fold Number 4/5
# Fold Number 5/5
#       Model Name   ROC AUC  Precision@K Mean  Recall@K Mean  F1_Score
# 0  XGBClassifier  0.842479          0.413293       0.809683     0.547

# %% [markdown]
# ### Performance Plotted

# %%
# Accumulative Gain
skplt.metrics.plot_cumulative_gain(y_val, yhat_xgboost, figsize = (10, 5));

# %%
# Lift Curve
skplt.metrics.plot_lift_curve( y_val, yhat_xgboost, figsize = (10, 5) );

# %% [markdown]
# ## LightGBM Classifier

# %% [markdown]
# ### Model Building

# %%
#define model
lgbm = LGBMClassifier(random_state = 22)

#train model
lgbm.fit( x_train, y_train)

#model prediction
yhat_lgbm = lgbm.predict_proba( x_val)

# %% [markdown]
# ### Model Single Performance

# %%
accuracy_lgbm = accuracy(lgbm, x_val, y_val, yhat_lgbm)
accuracy_lgbm
# Out:
#        Model Name  ROC AUC  Precision@K Mean  Recall@K Mean  F1_Score
# 0  LGBMClassifier  0.84505          0.415792       0.695836     0.521

# %% [markdown]
# ### Cross Validation Performance

# %%
accuracy_cv_lgbm = cross_validation(lgbm, x_train, y_train, 5, df6, Verbose = True)
accuracy_cv_lgbm
# Out:
# Fold Number 1/5
# Fold Number 2/5
# Fold Number 3/5
# Fold Number 4/5
# Fold Number 5/5
#        Model Name   ROC AUC  Precision@K Mean  Recall@K Mean  F1_Score
# 0  LGBMClassifier  0.844579          0.417791       0.810883     0.551

# %% [markdown]
# ### Performance Plotted

# %%
# Accumulative Gain
skplt.metrics.plot_cumulative_gain(y_val, yhat_lgbm, figsize = (10, 5));

# %%
# Lift Curve
skplt.metrics.plot_lift_curve( y_val, yhat_lgbm, figsize = (10, 5) );

# %% [markdown]
# ## CatBoost Classifier

# %% [markdown]
# ### Model Building

# %%
#define model
catboost = CatBoostClassifier(verbose = False, random_state = 22)

#train model
catboost.fit( x_train, y_train)

#model prediction
yhat_catboost = catboost.predict_proba( x_val)

# %% [markdown]
# ### Model Single Performance

# %%
accuracy_catboost = accuracy(catboost, x_val, y_val, yhat_catboost)
accuracy_catboost
# Out:
#            Model Name   ROC AUC  Precision@K Mean  Recall@K Mean  F1_Score
# 0  CatBoostClassifier  0.844024          0.393803       0.693667     0.502

# %% [markdown]
# ### Cross Validation Performance

# %%
accuracy_cv_catboost = cross_validation(catboost, x_train, y_train, 5, df6, Verbose = True)
accuracy_cv_catboost
# Out:
# Fold Number 1/5
# Fold Number 2/5
# Fold Number 3/5
# Fold Number 4/5
# Fold Number 5/5
#            Model Name   ROC AUC  Precision@K Mean  Recall@K Mean  F1_Score
# 0  CatBoostClassifier  0.844092            0.4008       0.813284     0.537

# %% [markdown]
# ### Performance Plotted

# %%
# Accumulative Gain
skplt.metrics.plot_cumulative_gain(y_val, yhat_catboost_tuned, figsize = (10, 5));

# %%
# Lift Curve
skplt.metrics.plot_lift_curve(y_val, yhat_catboost_tuned, figsize=(10, 5))

# %% [markdown]
# ## Comparing Models Preformance

# %% [markdown]
# ### Single Performance

# %%
models_results = pd.concat([accuracy_lr, accuracy_naive, accuracy_et, accuracy_rf, accuracy_knn, accuracy_xgboost, accuracy_lgbm, accuracy_catboost])
models_results.sort_values('Recall@K Mean', ascending = False)
# Out:
#                Model Name   ROC AUC  Precision@K Mean  Recall@K Mean  F1_Score
# 0          LGBMClassifier  0.845050          0.415792       0.695836     0.521
# 0      CatBoostClassifier  0.844024          0.393803       0.693667     0.502
# 0           XGBClassifier  0.844104          0.407296       0.691824     0.513
# 0  RandomForestClassifier  0.842642          0.398301       0.687486     0.504
# 0    ExtraTreesClassifier  0.809104          0.331834       0.621991     0.433
# 0    KNeighborsClassifier  0.779595          0.319340       0.619172     0.421
# 0              GaussianNB  0.811845          0.270865       0.609087     0.375
# 0      LogisticRegression  0.802364          0.264868       0.581653     0.364

# %% [markdown]
# ### Cross Validation Performance

# %%
models_results_cv = pd.concat([accuracy_cv_lr, accuracy_cv_naive, accuracy_cv_et, accuracy_cv_rf, accuracy_cv_knn, accuracy_cv_xgboost, accuracy_cv_lgbm, accuracy_cv_catboost])
models_results_cv.sort_values('Recall@K Mean', ascending = False)
# Out:
#                Model Name   ROC AUC  Precision@K Mean  Recall@K Mean  F1_Score
# 0      CatBoostClassifier  0.844092          0.400800       0.813284     0.537
# 0          LGBMClassifier  0.844579          0.417791       0.810883     0.551
# 0           XGBClassifier  0.842479          0.413293       0.809683     0.547
# 0  RandomForestClassifier  0.841617          0.398801       0.805815     0.534
# 0              GaussianNB  0.813100          0.283858       0.753668     0.412
# 0    ExtraTreesClassifier  0.811396          0.329835       0.748733     0.458
# 0    KNeighborsClassifier  0.779613          0.335832       0.726460     0.459
# 0      LogisticRegression  0.803912          0.277361       0.719392     0.400

# %% [markdown]
# # Hyperparameter Fine Tuning

# %% [markdown]
# ## Random Search

# %%
import random

param = {'depth' : [1, 2, 5, 10, 16],
         'iterations': [50, 100],
         'learning_rate' : [0.001, 0.01, 0.1, 0.2, 0.3],
         'l2_leaf_reg' : [1, 2, 5, 10, 100],
         'border_count' : [5, 25, 50, 100, 200],
         'random_state' : [22]
        }

MAX_EVAL = 10

# %%
final_result = pd.DataFrame({'ROC AUC': [], 'Precision@K Mean': [], 'Recall@K Mean': [], 'F1_Score': [] })

for i in range ( MAX_EVAL ):
    
    ## choose randomly values for parameters
    hp = { k: random.sample(v, 1)[0] for k, v in param.items() }
    print( 'Step ' +str(i +1) + '/' + str(MAX_EVAL))
    print( hp )
    # model
    model_catboost = CatBoostClassifier(depth=hp['depth'],
                          iterations = hp['iterations'],
                          learning_rate=hp['learning_rate'],
                          l2_leaf_reg=hp['l2_leaf_reg'],
                          border_count =hp['border_count'],
                          random_state=hp['random_state'])


    # performance
    model_catboost_result = cross_validation(model_catboost, x_train, y_train, 5, df6, Verbose = False)
    final_result = pd.concat([final_result, model_catboost_result])
    
final_result.sort_values('Recall@K Mean', ascending = False)
# Out:
# Step 1/10
# {'depth': 16, 'iterations': 250, 'learning_rate': 0.001, 'l2_leaf_reg': 1, 'border_count': 5, 'random_state': 22}
# Fold Number 1/5
# 0:	learn: 0.6916379	total: 53.6ms	remaining: 13.3s
# 1:	learn: 0.6901659	total: 105ms	remaining: 13s
# 2:	learn: 0.6886982	total: 145ms	remaining: 11.9s
# 3:	learn: 0.6871902	total: 220ms	remaining: 13.5s
# 4:	learn: 0.6856652	total: 315ms	remaining: 15.4s
# 5:	learn: 0.6841947	total: 394ms	remaining: 16s
# 6:	learn: 0.6827045	total: 478ms	remaining: 16.6s
# 7:	learn: 0.6812266	total: 537ms	remaining: 16.2s
# 8:	learn: 0.6797061	total: 648ms	remaining: 17.4s
# 9:	learn: 0.6781954	total: 726ms	remaining: 17.4s
# 10:	learn: 0.6766639	total: 856ms	remaining: 18.6s
# 11:	learn: 0.6751554	total: 946ms	remaining: 18.8s
# 12:	learn: 0.6736594	total: 1.06s	remaining: 19.4s
# 13:	learn: 0.6721618	total: 1.16s	remaining: 19.5s
# 14:	learn: 0.6707177	total: 1.24s	remaining: 19.5s
# 15:	learn: 0.6693097	total: 1.3s	remaining: 19s
# 16:	learn: 0.6678254	total: 1.4s	remaining: 19.1s
# 17:	learn: 0.6663626	total: 1.47s	remaining: 18.9s
# 18:	learn: 0.6648754	total: 1.58s	remaining: 19.2s
# 19:	learn: 0.6634303	total: 1.67s	remaining: 19.2s
# 20:	learn: 0.6619774	total: 1.74s	remaining: 19s
# 21:	learn: 0.6605256	total: 1.85s	remaining: 19.1s
# 22:	learn: 0.6590390	total: 3.63s	remaining: 35.8s
# 23:	learn: 0.6576677	total: 3.67s	remaining: 34.6s
# 24:	learn: 0.6562963	total: 3.73s	remaining: 33.6s
# 25:	learn: 0.6548729	total: 3.8s	remaining: 32.7s
# 26:	learn: 0.6534877	total: 3.86s	remaining: 31.9s
# 27:	learn: 0.6521093	total: 3.94s	remaining: 31.2s
# 28:	learn: 0.6507369	total: 4.03s	remaining: 30.7s
# 29:	learn: 0.6493969	total: 4.12s	remaining: 30.2s
# 30:	learn: 0.6480461	total: 4.21s	remaining: 29.8s
# 31:	learn: 0.6467153	total: 4.28s	remaining: 29.2s
# 32:	learn: 0.6453882	total: 4.33s	remaining: 28.5s
# 33:	learn: 0.6440790	total: 4.38s	remaining: 27.9s
# 34:	learn: 0.6427168	total: 4.46s	remaining: 27.4s
# 35:	learn: 0.6413817	total: 4.54s	remaining: 27s
# 36:	learn: 0.6400907	total: 4.59s	remaining: 26.4s
# 37:	learn: 0.6387925	total: 4.65s	remaining: 25.9s
# 38:	learn: 0.6374902	total: 4.7s	remaining: 25.4s
# 39:	learn: 0.6361855	total: 4.76s	remaining: 25s
# 40:	learn: 0.6348006	total: 5.27s	remaining: 26.9s
# 41:	learn: 0.6334439	total: 5.36s	remaining: 26.6s
# 42:	learn: 0.6321121	total: 5.43s	remaining: 26.2s
# 43:	learn: 0.6308376	total: 5.49s	remaining: 25.7s
# 44:	learn: 0.6295232	total: 5.66s	remaining: 25.8s
# 45:	learn: 0.6282156	total: 5.74s	remaining: 25.5s
# 46:	learn: 0.6269810	total: 5.79s	remaining: 25s
# 47:	learn: 0.6256382	total: 6.02s	remaining: 25.4s
# 48:	learn: 0.6243367	total: 6.09s	remaining: 25s
# 49:	learn: 0.6230575	total: 6.15s	remaining: 24.6s
# 50:	learn: 0.6217258	total: 6.34s	remaining: 24.7s
# 51:	learn: 0.6204366	total: 6.42s	remaining: 24.4s
# 52:	learn: 0.6192004	total: 6.47s	remaining: 24.1s
# 53:	learn: 0.6178861	total: 6.71s	remaining: 24.4s
# 54:	learn: 0.6166388	total: 6.78s	remaining: 24s
# 55:	learn: 0.6154035	total: 6.84s	remaining: 23.7s
# 56:	learn: 0.6141699	total: 6.91s	remaining: 23.4s
# 57:	learn: 0.6129111	total: 7.02s	remaining: 23.2s
# 58:	learn: 0.6116690	total: 7.08s	remaining: 22.9s
# 59:	learn: 0.6104308	total: 7.14s	remaining: 22.6s
# 60:	learn: 0.6092191	total: 7.21s	remaining: 22.3s
# 61:	learn: 0.6079689	total: 7.29s	remaining: 22.1s
# 62:	learn: 0.6067731	total: 7.34s	remaining: 21.8s
# 63:	learn: 0.6056172	total: 7.4s	remaining: 21.5s
# 64:	learn: 0.6044010	total: 7.46s	remaining: 21.2s
# 65:	learn: 0.6031919	total: 7.52s	remaining: 21s
# 66:	learn: 0.6019755	total: 7.62s	remaining: 20.8s
# 67:	learn: 0.6007637	total: 7.69s	remaining: 20.6s
# 68:	learn: 0.5995209	total: 8.19s	remaining: 21.5s
# 69:	learn: 0.5983661	total: 8.25s	remaining: 21.2s
# 70:	learn: 0.5972069	total: 8.31s	remaining: 20.9s
# 71:	learn: 0.5960148	total: 8.38s	remaining: 20.7s
# 72:	learn: 0.5948106	total: 8.5s	remaining: 20.6s
# 73:	learn: 0.5936690	total: 8.54s	remaining: 20.3s
# 74:	learn: 0.5925545	total: 8.59s	remaining: 20s
# 75:	learn: 0.5914298	total: 8.64s	remaining: 19.8s
# 76:	learn: 0.5902385	total: 8.76s	remaining: 19.7s
# 77:	learn: 0.5891247	total: 8.81s	remaining: 19.4s
# 78:	learn: 0.5879968	total: 8.89s	remaining: 19.2s
# 79:	learn: 0.5868506	total: 9s	remaining: 19.1s
# 80:	learn: 0.5857023	total: 9.08s	remaining: 18.9s
# 81:	learn: 0.5845653	total: 9.14s	remaining: 18.7s
# 82:	learn: 0.5834569	total: 9.2s	remaining: 18.5s
# 83:	learn: 0.5823861	total: 9.25s	remaining: 18.3s
# 84:	learn: 0.5812813	total: 9.33s	remaining: 18.1s
# 85:	learn: 0.5801721	total: 9.4s	remaining: 17.9s
# 86:	learn: 0.5790351	total: 9.51s	remaining: 17.8s
# 87:	learn: 0.5779359	total: 9.56s	remaining: 17.6s
# 88:	learn: 0.5768127	total: 9.64s	remaining: 17.4s
# 89:	learn: 0.5757450	total: 9.71s	remaining: 17.3s
# 90:	learn: 0.5746933	total: 9.75s	remaining: 17s
# 91:	learn: 0.5735928	total: 9.82s	remaining: 16.9s
# 92:	learn: 0.5725311	total: 9.91s	remaining: 16.7s
# 93:	learn: 0.5714093	total: 10.1s	remaining: 16.7s
# 94:	learn: 0.5703156	total: 10.1s	remaining: 16.6s
# 95:	learn: 0.5692193	total: 10.2s	remaining: 16.4s
# 96:	learn: 0.5681643	total: 10.3s	remaining: 16.3s
# 97:	learn: 0.5671170	total: 10.4s	remaining: 16.1s
# 98:	learn: 0.5660200	total: 10.5s	remaining: 16s
# 99:	learn: 0.5649459	total: 10.6s	remaining: 15.9s
# 100:	learn: 0.5638654	total: 10.7s	remaining: 15.7s
# 101:	learn: 0.5628331	total: 10.7s	remaining: 15.6s
# 102:	learn: 0.5617722	total: 10.8s	remaining: 15.4s
# 103:	learn: 0.5607361	total: 10.9s	remaining: 15.2s
# 104:	learn: 0.5596551	total: 11.4s	remaining: 15.7s
# 105:	learn: 0.5585997	total: 11.5s	remaining: 15.6s
# 106:	learn: 0.5575429	total: 11.6s	remaining: 15.5s
# 107:	learn: 0.5565430	total: 11.6s	remaining: 15.3s
# 108:	learn: 0.5554724	total: 12.2s	remaining: 15.8s
# 109:	learn: 0.5544763	total: 12.2s	remaining: 15.6s
# 110:	learn: 0.5534596	total: 12.3s	remaining: 15.4s
# 111:	learn: 0.5524493	total: 12.4s	remaining: 15.2s
# 112:	learn: 0.5514454	total: 12.4s	remaining: 15.1s
# 113:	learn: 0.5505170	total: 12.5s	remaining: 14.9s
# 114:	learn: 0.5495293	total: 12.5s	remaining: 14.7s
# 115:	learn: 0.5485070	total: 12.6s	remaining: 14.6s
# 116:	learn: 0.5474699	total: 13.1s	remaining: 14.9s
# 117:	learn: 0.5464783	total: 13.2s	remaining: 14.8s
# 118:	learn: 0.5455225	total: 13.2s	remaining: 14.6s
# 119:	learn: 0.5445877	total: 13.3s	remaining: 14.4s
# 120:	learn: 0.5436099	total: 13.4s	remaining: 14.2s
# 121:	learn: 0.5426345	total: 13.4s	remaining: 14.1s
# 122:	learn: 0.5416698	total: 13.5s	remaining: 13.9s
# 123:	learn: 0.5407232	total: 13.6s	remaining: 13.8s
# 124:	learn: 0.5397185	total: 13.7s	remaining: 13.7s
# 125:	learn: 0.5387358	total: 13.8s	remaining: 13.5s
# 126:	learn: 0.5377400	total: 15.4s	remaining: 15s
# 127:	learn: 0.5368025	total: 15.5s	remaining: 14.8s
# 128:	learn: 0.5358334	total: 15.7s	remaining: 14.8s
# 129:	learn: 0.5348710	total: 15.9s	remaining: 14.7s
# 130:	learn: 0.5339043	total: 16.1s	remaining: 14.6s
# 131:	learn: 0.5329419	total: 16.2s	remaining: 14.5s
# 132:	learn: 0.5320018	total: 16.3s	remaining: 14.3s
# 133:	learn: 0.5310813	total: 16.4s	remaining: 14.2s
# 134:	learn: 0.5301857	total: 16.4s	remaining: 14s
# 135:	learn: 0.5292569	total: 16.5s	remaining: 13.8s
# 136:	learn: 0.5283628	total: 16.5s	remaining: 13.7s
# 137:	learn: 0.5274484	total: 16.6s	remaining: 13.5s
# 138:	learn: 0.5265124	total: 16.7s	remaining: 13.4s
# 139:	learn: 0.5255855	total: 16.8s	remaining: 13.2s
# 140:	learn: 0.5246427	total: 17.3s	remaining: 13.4s
# 141:	learn: 0.5237767	total: 17.4s	remaining: 13.2s
# 142:	learn: 0.5228844	total: 17.4s	remaining: 13s
# 143:	learn: 0.5220156	total: 17.5s	remaining: 12.9s
# 144:	learn: 0.5211590	total: 17.5s	remaining: 12.7s
# 145:	learn: 0.5202447	total: 17.8s	remaining: 12.7s
# 146:	learn: 0.5193678	total: 17.9s	remaining: 12.5s
# 147:	learn: 0.5185199	total: 17.9s	remaining: 12.3s
# 148:	learn: 0.5176878	total: 17.9s	remaining: 12.2s
# 149:	learn: 0.5168482	total: 18s	remaining: 12s
# 150:	learn: 0.5159670	total: 18.1s	remaining: 11.9s
# 151:	learn: 0.5151028	total: 18.2s	remaining: 11.7s
# 152:	learn: 0.5142757	total: 18.2s	remaining: 11.5s
# 153:	learn: 0.5133914	total: 18.3s	remaining: 11.4s
# 154:	learn: 0.5125415	total: 18.4s	remaining: 11.3s
# 155:	learn: 0.5116723	total: 18.5s	remaining: 11.1s
# 156:	learn: 0.5108614	total: 18.5s	remaining: 11s
# 157:	learn: 0.5100222	total: 18.6s	remaining: 10.8s
# 158:	learn: 0.5091659	total: 18.7s	remaining: 10.7s
# 159:	learn: 0.5083317	total: 18.7s	remaining: 10.5s
# 160:	learn: 0.5074923	total: 18.8s	remaining: 10.4s
# 161:	learn: 0.5066814	total: 18.9s	remaining: 10.3s
# 162:	learn: 0.5058584	total: 18.9s	remaining: 10.1s
# 163:	learn: 0.5050141	total: 19s	remaining: 9.97s
# 164:	learn: 0.5042123	total: 19.1s	remaining: 9.83s
# 165:	learn: 0.5033823	total: 19.2s	remaining: 9.7s
# 166:	learn: 0.5025713	total: 19.3s	remaining: 9.57s
# 167:	learn: 0.5017764	total: 19.3s	remaining: 9.43s
# 168:	learn: 0.5009406	total: 19.5s	remaining: 9.33s
# 169:	learn: 0.5001516	total: 19.5s	remaining: 9.19s
# 170:	learn: 0.4993754	total: 19.6s	remaining: 9.05s
# 171:	learn: 0.4985855	total: 19.6s	remaining: 8.91s
# 172:	learn: 0.4977856	total: 19.7s	remaining: 8.77s
# 173:	learn: 0.4969885	total: 19.8s	remaining: 8.64s
# 174:	learn: 0.4961839	total: 19.9s	remaining: 8.51s
# 175:	learn: 0.4953973	total: 19.9s	remaining: 8.38s
# 176:	learn: 0.4946021	total: 20s	remaining: 8.25s
# 177:	learn: 0.4938092	total: 20.1s	remaining: 8.12s
# 178:	learn: 0.4930343	total: 20.2s	remaining: 8s
# 179:	learn: 0.4922530	total: 20.3s	remaining: 7.88s
# 180:	learn: 0.4914907	total: 20.3s	remaining: 7.75s
# 181:	learn: 0.4907460	total: 20.4s	remaining: 7.62s
# 182:	learn: 0.4899833	total: 20.5s	remaining: 7.49s
# 183:	learn: 0.4892116	total: 20.5s	remaining: 7.37s
# 184:	learn: 0.4884305	total: 20.6s	remaining: 7.25s
# 185:	learn: 0.4876582	total: 20.7s	remaining: 7.14s
# 186:	learn: 0.4869004	total: 20.8s	remaining: 7.02s
# 187:	learn: 0.4861541	total: 20.9s	remaining: 6.89s
# 188:	learn: 0.4853706	total: 22.6s	remaining: 7.28s
# 189:	learn: 0.4845999	total: 22.7s	remaining: 7.17s
# 190:	learn: 0.4838460	total: 22.8s	remaining: 7.05s
# 191:	learn: 0.4830946	total: 22.9s	remaining: 6.92s
# 192:	learn: 0.4823440	total: 23s	remaining: 6.79s
# 193:	learn: 0.4816039	total: 23.1s	remaining: 6.67s
# 194:	learn: 0.4808782	total: 23.2s	remaining: 6.53s
# 195:	learn: 0.4801511	total: 23.2s	remaining: 6.4s
# 196:	learn: 0.4794573	total: 23.3s	remaining: 6.26s
# 197:	learn: 0.4787034	total: 23.8s	remaining: 6.25s
# 198:	learn: 0.4779871	total: 23.9s	remaining: 6.11s
# 199:	learn: 0.4772475	total: 24s	remaining: 6s
# 200:	learn: 0.4765564	total: 24.1s	remaining: 5.87s
# 201:	learn: 0.4758650	total: 24.1s	remaining: 5.73s
# 202:	learn: 0.4751233	total: 24.4s	remaining: 5.64s
# 203:	learn: 0.4744106	total: 24.5s	remaining: 5.52s
# 204:	learn: 0.4736819	total: 24.6s	remaining: 5.39s
# 205:	learn: 0.4729838	total: 24.7s	remaining: 5.27s
# 206:	learn: 0.4723115	total: 24.7s	remaining: 5.13s
# 207:	learn: 0.4716294	total: 24.8s	remaining: 5s
# 208:	learn: 0.4709552	total: 24.9s	remaining: 4.88s
# 209:	learn: 0.4702433	total: 25s	remaining: 4.77s
# 210:	learn: 0.4695435	total: 25.1s	remaining: 4.64s
# 211:	learn: 0.4688634	total: 25.2s	remaining: 4.52s
# 212:	learn: 0.4681895	total: 25.3s	remaining: 4.39s
# 213:	learn: 0.4674999	total: 25.4s	remaining: 4.27s
# 214:	learn: 0.4668027	total: 25.5s	remaining: 4.15s
# 215:	learn: 0.4661112	total: 25.8s	remaining: 4.05s
# 216:	learn: 0.4654601	total: 25.8s	remaining: 3.92s
# 217:	learn: 0.4647920	total: 25.9s	remaining: 3.8s
# 218:	learn: 0.4641044	total: 26.1s	remaining: 3.69s
# 219:	learn: 0.4634524	total: 26.1s	remaining: 3.56s
# 220:	learn: 0.4627991	total: 26.2s	remaining: 3.44s
# 221:	learn: 0.4621388	total: 26.3s	remaining: 3.31s
# 222:	learn: 0.4614456	total: 28s	remaining: 3.39s
# 223:	learn: 0.4607981	total: 28.1s	remaining: 3.26s
# 224:	learn: 0.4601745	total: 28.1s	remaining: 3.12s
# 225:	learn: 0.4595783	total: 28.2s	remaining: 2.99s
# 226:	learn: 0.4589341	total: 28.2s	remaining: 2.86s
# 227:	learn: 0.4586232	total: 28.3s	remaining: 2.73s
# 228:	learn: 0.4579689	total: 28.4s	remaining: 2.6s
# 229:	learn: 0.4573003	total: 28.7s	remaining: 2.49s
# 230:	learn: 0.4566678	total: 28.7s	remaining: 2.36s
# 231:	learn: 0.4560177	total: 28.8s	remaining: 2.24s
# 232:	learn: 0.4553865	total: 28.9s	remaining: 2.11s
# 233:	learn: 0.4550809	total: 28.9s	remaining: 1.98s
# 234:	learn: 0.4544791	total: 29s	remaining: 1.85s
# 235:	learn: 0.4538541	total: 29.1s	remaining: 1.72s
# 236:	learn: 0.4532425	total: 29.1s	remaining: 1.6s
# 237:	learn: 0.4526064	total: 29.2s	remaining: 1.47s
# 238:	learn: 0.4519729	total: 29.3s	remaining: 1.35s
# 239:	learn: 0.4513816	total: 29.4s	remaining: 1.22s
# 240:	learn: 0.4507686	total: 29.5s	remaining: 1.1s
# 241:	learn: 0.4501403	total: 29.7s	remaining: 982ms
# 242:	learn: 0.4495354	total: 29.8s	remaining: 857ms
# 243:	learn: 0.4489303	total: 29.8s	remaining: 733ms
# 244:	learn: 0.4483548	total: 29.9s	remaining: 610ms
# 245:	learn: 0.4477681	total: 29.9s	remaining: 487ms
# 246:	learn: 0.4471553	total: 30.2s	remaining: 366ms
# 247:	learn: 0.4465322	total: 31.3s	remaining: 252ms
# 248:	learn: 0.4459491	total: 31.3s	remaining: 126ms
# 249:	learn: 0.4453464	total: 31.4s	remaining: 0us
# Fold Number 2/5
# 0:	learn: 0.6916422	total: 57.8ms	remaining: 14.4s
# 1:	learn: 0.6901260	total: 136ms	remaining: 16.9s
# 2:	learn: 0.6885966	total: 201ms	remaining: 16.6s
# 3:	learn: 0.6871079	total: 251ms	remaining: 15.5s
# 4:	learn: 0.6855674	total: 407ms	remaining: 20s
# 5:	learn: 0.6840681	total: 451ms	remaining: 18.3s
# 6:	learn: 0.6826013	total: 512ms	remaining: 17.8s
# 7:	learn: 0.6811305	total: 561ms	remaining: 17s
# 8:	learn: 0.6796548	total: 612ms	remaining: 16.4s
# 9:	learn: 0.6781562	total: 674ms	remaining: 16.2s
# 10:	learn: 0.6766816	total: 741ms	remaining: 16.1s
# 11:	learn: 0.6751813	total: 850ms	remaining: 16.9s
# 12:	learn: 0.6737408	total: 910ms	remaining: 16.6s
# 13:	learn: 0.6722254	total: 1.14s	remaining: 19.2s
# 14:	learn: 0.6708063	total: 1.19s	remaining: 18.7s
# 15:	learn: 0.6693515	total: 1.26s	remaining: 18.4s
# 16:	learn: 0.6679629	total: 1.3s	remaining: 17.8s
# 17:	learn: 0.6665458	total: 1.36s	remaining: 17.5s
# 18:	learn: 0.6650813	total: 1.48s	remaining: 18s
# 19:	learn: 0.6636562	total: 1.54s	remaining: 17.8s
# 20:	learn: 0.6621721	total: 2.04s	remaining: 22.2s
# 21:	learn: 0.6607516	total: 2.11s	remaining: 21.9s
# 22:	learn: 0.6593229	total: 2.18s	remaining: 21.5s
# 23:	learn: 0.6578736	total: 2.29s	remaining: 21.5s
# 24:	learn: 0.6564121	total: 4.01s	remaining: 36.1s
# 25:	learn: 0.6550530	total: 4.05s	remaining: 34.9s
# 26:	learn: 0.6536932	total: 4.11s	remaining: 33.9s
# 27:	learn: 0.6522867	total: 4.18s	remaining: 33.2s
# 28:	learn: 0.6509206	total: 4.24s	remaining: 32.3s
# 29:	learn: 0.6495518	total: 4.32s	remaining: 31.6s
# 30:	learn: 0.6482006	total: 4.39s	remaining: 31s
# 31:	learn: 0.6468753	total: 4.44s	remaining: 30.2s
# 32:	learn: 0.6455379	total: 4.5s	remaining: 29.6s
# 33:	learn: 0.6442085	total: 4.56s	remaining: 29s
# 34:	learn: 0.6429098	total: 4.6s	remaining: 28.3s
# 35:	learn: 0.6415468	total: 4.72s	remaining: 28.1s
# 36:	learn: 0.6401869	total: 4.8s	remaining: 27.6s
# 37:	learn: 0.6388586	total: 4.88s	remaining: 27.2s
# 38:	learn: 0.6375251	total: 4.96s	remaining: 26.8s
# 39:	learn: 0.6361576	total: 5.1s	remaining: 26.8s
# 40:	learn: 0.6348874	total: 5.16s	remaining: 26.3s
# 41:	learn: 0.6335948	total: 5.21s	remaining: 25.8s
# 42:	learn: 0.6322396	total: 5.32s	remaining: 25.6s
# 43:	learn: 0.6309142	total: 5.4s	remaining: 25.3s
# 44:	learn: 0.6296150	total: 5.48s	remaining: 25s
# 45:	learn: 0.6283364	total: 5.53s	remaining: 24.5s
# 46:	learn: 0.6270612	total: 5.6s	remaining: 24.2s
# 47:	learn: 0.6258068	total: 5.66s	remaining: 23.8s
# 48:	learn: 0.6244782	total: 5.88s	remaining: 24.1s
# 49:	learn: 0.6231890	total: 5.94s	remaining: 23.8s
# 50:	learn: 0.6219185	total: 6s	remaining: 23.4s
# 51:	learn: 0.6205984	total: 6.18s	remaining: 23.5s
# 52:	learn: 0.6193230	total: 6.26s	remaining: 23.3s
# 53:	learn: 0.6180921	total: 6.32s	remaining: 22.9s
# 54:	learn: 0.6167894	total: 6.54s	remaining: 23.2s
# 55:	learn: 0.6155495	total: 6.62s	remaining: 22.9s
# 56:	learn: 0.6143229	total: 6.67s	remaining: 22.6s
# 57:	learn: 0.6130991	total: 6.74s	remaining: 22.3s
# 58:	learn: 0.6118436	total: 6.85s	remaining: 22.2s
# 59:	learn: 0.6106123	total: 6.91s	remaining: 21.9s
# 60:	learn: 0.6093796	total: 6.98s	remaining: 21.6s
# 61:	learn: 0.6081762	total: 7.03s	remaining: 21.3s
# 62:	learn: 0.6069369	total: 7.11s	remaining: 21.1s
# 63:	learn: 0.6057466	total: 7.16s	remaining: 20.8s
# 64:	learn: 0.6045992	total: 7.22s	remaining: 20.6s
# 65:	learn: 0.6033963	total: 7.28s	remaining: 20.3s
# 66:	learn: 0.6022335	total: 7.33s	remaining: 20s
# 67:	learn: 0.6009960	total: 7.49s	remaining: 20s
# 68:	learn: 0.5998422	total: 7.55s	remaining: 19.8s
# 69:	learn: 0.5986437	total: 7.65s	remaining: 19.7s
# 70:	learn: 0.5974376	total: 7.75s	remaining: 19.5s
# 71:	learn: 0.5962853	total: 7.8s	remaining: 19.3s
# 72:	learn: 0.5950575	total: 8.97s	remaining: 21.7s
# 73:	learn: 0.5939204	total: 9.02s	remaining: 21.5s
# 74:	learn: 0.5927527	total: 9.09s	remaining: 21.2s
# 75:	learn: 0.5915278	total: 10.9s	remaining: 24.9s
# 76:	learn: 0.5903769	total: 10.9s	remaining: 24.5s
# 77:	learn: 0.5892397	total: 11s	remaining: 24.2s
# 78:	learn: 0.5881210	total: 11s	remaining: 23.9s
# 79:	learn: 0.5869770	total: 11.1s	remaining: 23.6s
# 80:	learn: 0.5858338	total: 11.2s	remaining: 23.3s
# 81:	learn: 0.5847401	total: 11.2s	remaining: 23s
# 82:	learn: 0.5835986	total: 11.3s	remaining: 22.8s
# 83:	learn: 0.5824972	total: 11.4s	remaining: 22.5s
# 84:	learn: 0.5813245	total: 13.2s	remaining: 25.5s
# 85:	learn: 0.5802144	total: 13.2s	remaining: 25.2s
# 86:	learn: 0.5791371	total: 13.3s	remaining: 24.9s
# 87:	learn: 0.5779990	total: 13.4s	remaining: 24.7s
# 88:	learn: 0.5769315	total: 13.5s	remaining: 24.4s
# 89:	learn: 0.5758737	total: 13.5s	remaining: 24s
# 90:	learn: 0.5747955	total: 13.6s	remaining: 23.8s
# 91:	learn: 0.5736706	total: 13.8s	remaining: 23.6s
# 92:	learn: 0.5725736	total: 13.8s	remaining: 23.4s
# 93:	learn: 0.5714736	total: 13.9s	remaining: 23.1s
# 94:	learn: 0.5704123	total: 14s	remaining: 22.8s
# 95:	learn: 0.5693614	total: 14s	remaining: 22.5s
# 96:	learn: 0.5682524	total: 14.3s	remaining: 22.5s
# 97:	learn: 0.5671794	total: 14.3s	remaining: 22.2s
# 98:	learn: 0.5660911	total: 14.4s	remaining: 22s
# 99:	learn: 0.5650603	total: 14.5s	remaining: 21.7s
# 100:	learn: 0.5639784	total: 14.6s	remaining: 21.5s
# 101:	learn: 0.5629174	total: 14.7s	remaining: 21.3s
# 102:	learn: 0.5618766	total: 14.7s	remaining: 21s
# 103:	learn: 0.5608247	total: 14.8s	remaining: 20.8s
# 104:	learn: 0.5598340	total: 14.8s	remaining: 20.5s
# 105:	learn: 0.5587851	total: 14.9s	remaining: 20.3s
# 106:	learn: 0.5577857	total: 15s	remaining: 20s
# 107:	learn: 0.5567122	total: 15.5s	remaining: 20.4s
# 108:	learn: 0.5557150	total: 15.6s	remaining: 20.1s
# 109:	learn: 0.5547531	total: 15.6s	remaining: 19.8s
# 110:	learn: 0.5537903	total: 15.6s	remaining: 19.6s
# 111:	learn: 0.5527735	total: 15.7s	remaining: 19.3s
# 112:	learn: 0.5517650	total: 15.8s	remaining: 19.1s
# 113:	learn: 0.5507554	total: 15.8s	remaining: 18.9s
# 114:	learn: 0.5497630	total: 15.9s	remaining: 18.7s
# 115:	learn: 0.5487983	total: 16s	remaining: 18.5s
# 116:	learn: 0.5478408	total: 16s	remaining: 18.2s
# 117:	learn: 0.5468559	total: 16.1s	remaining: 18s
# 118:	learn: 0.5459191	total: 16.1s	remaining: 17.8s
# 119:	learn: 0.5449318	total: 16.2s	remaining: 17.6s
# 120:	learn: 0.5439750	total: 16.3s	remaining: 17.4s
# 121:	learn: 0.5429599	total: 17.5s	remaining: 18.4s
# 122:	learn: 0.5419877	total: 17.6s	remaining: 18.1s
# 123:	learn: 0.5410580	total: 17.6s	remaining: 17.9s
# 124:	learn: 0.5400638	total: 17.7s	remaining: 17.7s
# 125:	learn: 0.5390634	total: 19.5s	remaining: 19.2s
# 126:	learn: 0.5381046	total: 19.6s	remaining: 19s
# 127:	learn: 0.5371215	total: 19.8s	remaining: 18.8s
# 128:	learn: 0.5361907	total: 19.8s	remaining: 18.6s
# 129:	learn: 0.5352695	total: 19.9s	remaining: 18.4s
# 130:	learn: 0.5343111	total: 20s	remaining: 18.2s
# 131:	learn: 0.5333770	total: 20.1s	remaining: 17.9s
# 132:	learn: 0.5324687	total: 20.1s	remaining: 17.7s
# 133:	learn: 0.5315278	total: 20.2s	remaining: 17.5s
# 134:	learn: 0.5306101	total: 20.3s	remaining: 17.3s
# 135:	learn: 0.5296423	total: 22.1s	remaining: 18.5s
# 136:	learn: 0.5287614	total: 22.1s	remaining: 18.2s
# 137:	learn: 0.5278540	total: 22.2s	remaining: 18s
# 138:	learn: 0.5269587	total: 22.2s	remaining: 17.8s
# 139:	learn: 0.5260603	total: 22.3s	remaining: 17.6s
# 140:	learn: 0.5251569	total: 22.4s	remaining: 17.3s
# 141:	learn: 0.5242530	total: 22.5s	remaining: 17.1s
# 142:	learn: 0.5233579	total: 22.6s	remaining: 16.9s
# 143:	learn: 0.5224666	total: 22.6s	remaining: 16.7s
# 144:	learn: 0.5215821	total: 22.7s	remaining: 16.4s
# 145:	learn: 0.5207293	total: 22.8s	remaining: 16.2s
# 146:	learn: 0.5198332	total: 22.9s	remaining: 16s
# 147:	learn: 0.5190014	total: 22.9s	remaining: 15.8s
# 148:	learn: 0.5181592	total: 22.9s	remaining: 15.6s
# 149:	learn: 0.5173243	total: 23s	remaining: 15.3s
# 150:	learn: 0.5164762	total: 23.1s	remaining: 15.1s
# 151:	learn: 0.5156174	total: 23.1s	remaining: 14.9s
# 152:	learn: 0.5147444	total: 23.2s	remaining: 14.7s
# 153:	learn: 0.5138640	total: 23.3s	remaining: 14.5s
# 154:	learn: 0.5129859	total: 23.6s	remaining: 14.4s
# 155:	learn: 0.5120927	total: 24.7s	remaining: 14.9s
# 156:	learn: 0.5112109	total: 25.9s	remaining: 15.4s
# 157:	learn: 0.5103944	total: 26s	remaining: 15.1s
# 158:	learn: 0.5095185	total: 27.1s	remaining: 15.5s
# 159:	learn: 0.5086815	total: 27.2s	remaining: 15.3s
# 160:	learn: 0.5078961	total: 27.3s	remaining: 15.1s
# 161:	learn: 0.5070736	total: 27.3s	remaining: 14.8s
# 162:	learn: 0.5062442	total: 27.4s	remaining: 14.6s
# 163:	learn: 0.5053969	total: 27.5s	remaining: 14.4s
# 164:	learn: 0.5045919	total: 27.6s	remaining: 14.2s
# 165:	learn: 0.5037293	total: 28.7s	remaining: 14.5s
# 166:	learn: 0.5029019	total: 28.8s	remaining: 14.3s
# 167:	learn: 0.5020969	total: 28.9s	remaining: 14.1s
# 168:	learn: 0.5013136	total: 28.9s	remaining: 13.9s
# 169:	learn: 0.5005363	total: 29s	remaining: 13.6s
# 170:	learn: 0.4997382	total: 29.1s	remaining: 13.4s
# 171:	learn: 0.4989290	total: 29.1s	remaining: 13.2s
# 172:	learn: 0.4981121	total: 29.2s	remaining: 13s
# 173:	learn: 0.4973240	total: 29.3s	remaining: 12.8s
# 174:	learn: 0.4965236	total: 29.4s	remaining: 12.6s
# 175:	learn: 0.4957533	total: 29.5s	remaining: 12.4s
# 176:	learn: 0.4950080	total: 29.5s	remaining: 12.2s
# 177:	learn: 0.4942518	total: 29.6s	remaining: 12s
# 178:	learn: 0.4934652	total: 29.7s	remaining: 11.8s
# 179:	learn: 0.4926728	total: 29.8s	remaining: 11.6s
# 180:	learn: 0.4918864	total: 29.9s	remaining: 11.4s
# 181:	learn: 0.4911138	total: 30s	remaining: 11.2s
# 182:	learn: 0.4903527	total: 30s	remaining: 11s
# 183:	learn: 0.4895533	total: 31.7s	remaining: 11.4s
# 184:	learn: 0.4887733	total: 31.9s	remaining: 11.2s
# 185:	learn: 0.4880021	total: 32s	remaining: 11s
# 186:	learn: 0.4872396	total: 32.1s	remaining: 10.8s
# 187:	learn: 0.4864756	total: 32.2s	remaining: 10.6s
# 188:	learn: 0.4857222	total: 32.3s	remaining: 10.4s
# 189:	learn: 0.4849809	total: 32.4s	remaining: 10.2s
# 190:	learn: 0.4842784	total: 32.4s	remaining: 10s
# 191:	learn: 0.4835582	total: 32.5s	remaining: 9.81s
# 192:	learn: 0.4828532	total: 32.5s	remaining: 9.61s
# 193:	learn: 0.4821377	total: 32.6s	remaining: 9.41s
# 194:	learn: 0.4814380	total: 32.7s	remaining: 9.21s
# 195:	learn: 0.4806910	total: 32.8s	remaining: 9.03s
# 196:	learn: 0.4799938	total: 32.8s	remaining: 8.83s
# 197:	learn: 0.4792781	total: 32.9s	remaining: 8.64s
# 198:	learn: 0.4785683	total: 33s	remaining: 8.45s
# 199:	learn: 0.4778455	total: 33s	remaining: 8.26s
# 200:	learn: 0.4771328	total: 33.1s	remaining: 8.08s
# 201:	learn: 0.4764050	total: 33.2s	remaining: 7.9s
# 202:	learn: 0.4756952	total: 33.3s	remaining: 7.71s
# 203:	learn: 0.4750131	total: 33.4s	remaining: 7.53s
# 204:	learn: 0.4743081	total: 33.5s	remaining: 7.34s
# 205:	learn: 0.4736351	total: 33.5s	remaining: 7.16s
# 206:	learn: 0.4729414	total: 33.6s	remaining: 6.98s
# 207:	learn: 0.4722021	total: 35.3s	remaining: 7.14s
# 208:	learn: 0.4715235	total: 35.4s	remaining: 6.95s
# 209:	learn: 0.4708175	total: 35.5s	remaining: 6.76s
# 210:	learn: 0.4701213	total: 35.6s	remaining: 6.58s
# 211:	learn: 0.4694245	total: 35.7s	remaining: 6.4s
# 212:	learn: 0.4687297	total: 35.9s	remaining: 6.23s
# 213:	learn: 0.4680414	total: 36s	remaining: 6.05s
# 214:	learn: 0.4673558	total: 36.1s	remaining: 5.88s
# 215:	learn: 0.4666883	total: 36.2s	remaining: 5.7s
# 216:	learn: 0.4660297	total: 36.3s	remaining: 5.51s
# 217:	learn: 0.4653648	total: 36.3s	remaining: 5.33s
# 218:	learn: 0.4646812	total: 36.5s	remaining: 5.16s
# 219:	learn: 0.4639889	total: 38.3s	remaining: 5.22s
# 220:	learn: 0.4633082	total: 38.4s	remaining: 5.04s
# 221:	learn: 0.4626644	total: 38.5s	remaining: 4.85s
# 222:	learn: 0.4620014	total: 38.6s	remaining: 4.67s
# 223:	learn: 0.4613672	total: 38.6s	remaining: 4.48s
# 224:	learn: 0.4606865	total: 38.9s	remaining: 4.32s
# 225:	learn: 0.4600397	total: 38.9s	remaining: 4.13s
# 226:	learn: 0.4593814	total: 39.1s	remaining: 3.96s
# 227:	learn: 0.4587401	total: 39.1s	remaining: 3.78s
# 228:	learn: 0.4584272	total: 39.2s	remaining: 3.59s
# 229:	learn: 0.4578153	total: 39.2s	remaining: 3.41s
# 230:	learn: 0.4571978	total: 39.3s	remaining: 3.23s
# 231:	learn: 0.4565564	total: 39.4s	remaining: 3.05s
# 232:	learn: 0.4559343	total: 39.4s	remaining: 2.88s
# 233:	learn: 0.4553335	total: 39.5s	remaining: 2.7s
# 234:	learn: 0.4547083	total: 39.6s	remaining: 2.52s
# 235:	learn: 0.4541125	total: 39.6s	remaining: 2.35s
# 236:	learn: 0.4535102	total: 39.7s	remaining: 2.17s
# 237:	learn: 0.4528707	total: 39.8s	remaining: 2.01s
# 238:	learn: 0.4522792	total: 39.9s	remaining: 1.83s
# 239:	learn: 0.4516876	total: 39.9s	remaining: 1.66s
# 240:	learn: 0.4510992	total: 40s	remaining: 1.49s
# 241:	learn: 0.4504913	total: 40.1s	remaining: 1.32s
# 242:	learn: 0.4498725	total: 40.2s	remaining: 1.16s
# 243:	learn: 0.4492767	total: 40.3s	remaining: 991ms
# 244:	learn: 0.4486558	total: 40.5s	remaining: 827ms
# 245:	learn: 0.4480495	total: 40.6s	remaining: 661ms
# 246:	learn: 0.4474538	total: 40.8s	remaining: 496ms
# 247:	learn: 0.4468565	total: 40.9s	remaining: 330ms
# 248:	learn: 0.4462816	total: 40.9s	remaining: 164ms
# 249:	learn: 0.4456985	total: 41s	remaining: 0us
# Fold Number 3/5
# 0:	learn: 0.6916395	total: 57.6ms	remaining: 14.4s
# 1:	learn: 0.6901494	total: 110ms	remaining: 13.7s
# 2:	learn: 0.6887236	total: 146ms	remaining: 12s
# 3:	learn: 0.6872027	total: 214ms	remaining: 13.2s
# 4:	learn: 0.6857028	total: 290ms	remaining: 14.2s
# 5:	learn: 0.6841839	total: 361ms	remaining: 14.7s
# 6:	learn: 0.6827027	total: 442ms	remaining: 15.3s
# 7:	learn: 0.6812363	total: 493ms	remaining: 14.9s
# 8:	learn: 0.6797357	total: 575ms	remaining: 15.4s
# 9:	learn: 0.6782721	total: 624ms	remaining: 15s
# 10:	learn: 0.6767487	total: 741ms	remaining: 16.1s
# 11:	learn: 0.6753284	total: 789ms	remaining: 15.7s
# 12:	learn: 0.6738198	total: 868ms	remaining: 15.8s
# 13:	learn: 0.6723960	total: 913ms	remaining: 15.4s
# 14:	learn: 0.6709672	total: 986ms	remaining: 15.4s
# 15:	learn: 0.6694794	total: 1.06s	remaining: 15.5s
# 16:	learn: 0.6680856	total: 1.1s	remaining: 15.1s
# 17:	learn: 0.6666326	total: 1.18s	remaining: 15.2s
# 18:	learn: 0.6651735	total: 1.27s	remaining: 15.4s
# 19:	learn: 0.6637159	total: 1.33s	remaining: 15.4s
# 20:	learn: 0.6622750	total: 1.42s	remaining: 15.5s
# 21:	learn: 0.6608327	total: 1.49s	remaining: 15.5s
# 22:	learn: 0.6594549	total: 1.56s	remaining: 15.4s
# 23:	learn: 0.6579784	total: 3.33s	remaining: 31.3s
# 24:	learn: 0.6566294	total: 3.36s	remaining: 30.3s
# 25:	learn: 0.6552577	total: 3.42s	remaining: 29.5s
# 26:	learn: 0.6538104	total: 3.59s	remaining: 29.7s
# 27:	learn: 0.6524047	total: 3.68s	remaining: 29.2s
# 28:	learn: 0.6509617	total: 4.21s	remaining: 32.1s
# 29:	learn: 0.6495845	total: 4.27s	remaining: 31.3s
# 30:	learn: 0.6482145	total: 4.32s	remaining: 30.5s
# 31:	learn: 0.6468667	total: 4.37s	remaining: 29.7s
# 32:	learn: 0.6454885	total: 4.5s	remaining: 29.6s
# 33:	learn: 0.6441830	total: 4.54s	remaining: 28.8s
# 34:	learn: 0.6428139	total: 4.61s	remaining: 28.3s
# 35:	learn: 0.6414837	total: 4.68s	remaining: 27.8s
# 36:	learn: 0.6401532	total: 4.78s	remaining: 27.5s
# 37:	learn: 0.6388063	total: 4.86s	remaining: 27.1s
# 38:	learn: 0.6374288	total: 5.03s	remaining: 27.2s
# 39:	learn: 0.6361461	total: 5.08s	remaining: 26.7s
# 40:	learn: 0.6348396	total: 5.12s	remaining: 26.1s
# 41:	learn: 0.6334873	total: 5.24s	remaining: 25.9s
# 42:	learn: 0.6321597	total: 5.31s	remaining: 25.6s
# 43:	learn: 0.6308645	total: 5.39s	remaining: 25.3s
# 44:	learn: 0.6295782	total: 5.46s	remaining: 24.9s
# 45:	learn: 0.6282821	total: 5.52s	remaining: 24.5s
# 46:	learn: 0.6270350	total: 5.57s	remaining: 24s
# 47:	learn: 0.6256940	total: 5.78s	remaining: 24.3s
# 48:	learn: 0.6243941	total: 5.85s	remaining: 24s
# 49:	learn: 0.6231142	total: 5.91s	remaining: 23.6s
# 50:	learn: 0.6218864	total: 5.95s	remaining: 23.2s
# 51:	learn: 0.6206668	total: 6.01s	remaining: 22.9s
# 52:	learn: 0.6193664	total: 6.1s	remaining: 22.7s
# 53:	learn: 0.6181600	total: 6.14s	remaining: 22.3s
# 54:	learn: 0.6169350	total: 6.21s	remaining: 22s
# 55:	learn: 0.6156714	total: 6.28s	remaining: 21.7s
# 56:	learn: 0.6143834	total: 7.57s	remaining: 25.6s
# 57:	learn: 0.6131809	total: 7.62s	remaining: 25.2s
# 58:	learn: 0.6119678	total: 7.67s	remaining: 24.8s
# 59:	learn: 0.6107711	total: 7.72s	remaining: 24.5s
# 60:	learn: 0.6095155	total: 7.89s	remaining: 24.5s
# 61:	learn: 0.6083244	total: 7.94s	remaining: 24.1s
# 62:	learn: 0.6071165	total: 8s	remaining: 23.7s
# 63:	learn: 0.6059046	total: 8.06s	remaining: 23.4s
# 64:	learn: 0.6046827	total: 8.14s	remaining: 23.2s
# 65:	learn: 0.6035013	total: 8.2s	remaining: 22.9s
# 66:	learn: 0.6023060	total: 8.26s	remaining: 22.6s
# 67:	learn: 0.6011351	total: 8.31s	remaining: 22.2s
# 68:	learn: 0.5999295	total: 8.41s	remaining: 22.1s
# 69:	learn: 0.5987296	total: 8.51s	remaining: 21.9s
# 70:	learn: 0.5975329	total: 8.57s	remaining: 21.6s
# 71:	learn: 0.5962938	total: 9.1s	remaining: 22.5s
# 72:	learn: 0.5950988	total: 9.19s	remaining: 22.3s
# 73:	learn: 0.5939314	total: 9.24s	remaining: 22s
# 74:	learn: 0.5928212	total: 9.3s	remaining: 21.7s
# 75:	learn: 0.5916989	total: 9.37s	remaining: 21.5s
# 76:	learn: 0.5905269	total: 9.44s	remaining: 21.2s
# 77:	learn: 0.5893612	total: 9.52s	remaining: 21s
# 78:	learn: 0.5881737	total: 9.61s	remaining: 20.8s
# 79:	learn: 0.5870251	total: 9.72s	remaining: 20.7s
# 80:	learn: 0.5859149	total: 9.79s	remaining: 20.4s
# 81:	learn: 0.5847985	total: 9.84s	remaining: 20.2s
# 82:	learn: 0.5836742	total: 9.9s	remaining: 19.9s
# 83:	learn: 0.5825669	total: 9.96s	remaining: 19.7s
# 84:	learn: 0.5814397	total: 10s	remaining: 19.5s
# 85:	learn: 0.5803304	total: 10.1s	remaining: 19.3s
# 86:	learn: 0.5792636	total: 10.1s	remaining: 19s
# 87:	learn: 0.5781966	total: 10.2s	remaining: 18.8s
# 88:	learn: 0.5771266	total: 10.2s	remaining: 18.5s
# 89:	learn: 0.5760047	total: 10.4s	remaining: 18.4s
# 90:	learn: 0.5749276	total: 10.4s	remaining: 18.2s
# 91:	learn: 0.5738353	total: 10.5s	remaining: 18s
# 92:	learn: 0.5727051	total: 10.7s	remaining: 18.1s
# 93:	learn: 0.5715962	total: 10.8s	remaining: 18s
# 94:	learn: 0.5705673	total: 10.9s	remaining: 17.7s
# 95:	learn: 0.5695386	total: 10.9s	remaining: 17.5s
# 96:	learn: 0.5684096	total: 12.2s	remaining: 19.2s
# 97:	learn: 0.5673840	total: 12.2s	remaining: 18.9s
# 98:	learn: 0.5663973	total: 12.2s	remaining: 18.7s
# 99:	learn: 0.5653813	total: 12.3s	remaining: 18.5s
# 100:	learn: 0.5643193	total: 12.4s	remaining: 18.3s
# 101:	learn: 0.5633309	total: 12.4s	remaining: 18s
# 102:	learn: 0.5623122	total: 12.5s	remaining: 17.8s
# 103:	learn: 0.5612998	total: 12.6s	remaining: 17.6s
# 104:	learn: 0.5602280	total: 12.7s	remaining: 17.5s
# 105:	learn: 0.5592158	total: 12.7s	remaining: 17.3s
# 106:	learn: 0.5581537	total: 12.8s	remaining: 17.1s
# 107:	learn: 0.5571213	total: 12.9s	remaining: 17s
# 108:	learn: 0.5561084	total: 13s	remaining: 16.8s
# 109:	learn: 0.5550801	total: 13s	remaining: 16.6s
# 110:	learn: 0.5541092	total: 13.1s	remaining: 16.4s
# 111:	learn: 0.5530882	total: 13.2s	remaining: 16.2s
# 112:	learn: 0.5520607	total: 13.3s	remaining: 16.1s
# 113:	learn: 0.5510237	total: 13.4s	remaining: 16s
# 114:	learn: 0.5500197	total: 13.4s	remaining: 15.8s
# 115:	learn: 0.5490289	total: 13.5s	remaining: 15.6s
# 116:	learn: 0.5479993	total: 13.7s	remaining: 15.6s
# 117:	learn: 0.5470365	total: 13.7s	remaining: 15.4s
# 118:	learn: 0.5460188	total: 13.8s	remaining: 15.2s
# 119:	learn: 0.5450247	total: 14s	remaining: 15.1s
# 120:	learn: 0.5440538	total: 14s	remaining: 14.9s
# 121:	learn: 0.5431184	total: 14.1s	remaining: 14.7s
# 122:	learn: 0.5421240	total: 14.2s	remaining: 14.6s
# 123:	learn: 0.5411727	total: 14.2s	remaining: 14.5s
# 124:	learn: 0.5401666	total: 15.5s	remaining: 15.5s
# 125:	learn: 0.5392014	total: 15.6s	remaining: 15.3s
# 126:	learn: 0.5382751	total: 15.6s	remaining: 15.1s
# 127:	learn: 0.5373295	total: 15.7s	remaining: 14.9s
# 128:	learn: 0.5363783	total: 15.8s	remaining: 14.8s
# 129:	learn: 0.5354791	total: 15.8s	remaining: 14.6s
# 130:	learn: 0.5345033	total: 15.9s	remaining: 14.5s
# 131:	learn: 0.5335549	total: 16s	remaining: 14.3s
# 132:	learn: 0.5326215	total: 16.1s	remaining: 14.1s
# 133:	learn: 0.5316856	total: 16.1s	remaining: 14s
# 134:	learn: 0.5307313	total: 16.3s	remaining: 13.9s
# 135:	learn: 0.5297930	total: 16.4s	remaining: 13.8s
# 136:	learn: 0.5288682	total: 16.5s	remaining: 13.6s
# 137:	learn: 0.5279686	total: 16.6s	remaining: 13.5s
# 138:	learn: 0.5270891	total: 16.6s	remaining: 13.3s
# 139:	learn: 0.5262173	total: 16.7s	remaining: 13.1s
# 140:	learn: 0.5253046	total: 16.8s	remaining: 13s
# 141:	learn: 0.5244444	total: 16.8s	remaining: 12.8s
# 142:	learn: 0.5235268	total: 16.9s	remaining: 12.7s
# 143:	learn: 0.5226430	total: 17s	remaining: 12.5s
# 144:	learn: 0.5217492	total: 17.1s	remaining: 12.4s
# 145:	learn: 0.5208694	total: 17.1s	remaining: 12.2s
# 146:	learn: 0.5199511	total: 17.3s	remaining: 12.2s
# 147:	learn: 0.5191217	total: 17.4s	remaining: 12s
# 148:	learn: 0.5182615	total: 17.4s	remaining: 11.8s
# 149:	learn: 0.5173896	total: 17.5s	remaining: 11.7s
# 150:	learn: 0.5165604	total: 17.5s	remaining: 11.5s
# 151:	learn: 0.5157082	total: 17.6s	remaining: 11.4s
# 152:	learn: 0.5148762	total: 17.7s	remaining: 11.2s
# 153:	learn: 0.5140313	total: 17.7s	remaining: 11s
# 154:	learn: 0.5131298	total: 19s	remaining: 11.6s
# 155:	learn: 0.5122809	total: 19.1s	remaining: 11.5s
# 156:	learn: 0.5114172	total: 19.2s	remaining: 11.4s
# 157:	learn: 0.5105535	total: 19.3s	remaining: 11.2s
# 158:	learn: 0.5096794	total: 19.5s	remaining: 11.2s
# 159:	learn: 0.5088446	total: 19.6s	remaining: 11s
# 160:	learn: 0.5080333	total: 19.6s	remaining: 10.8s
# 161:	learn: 0.5072365	total: 19.7s	remaining: 10.7s
# 162:	learn: 0.5064086	total: 19.7s	remaining: 10.5s
# 163:	learn: 0.5055822	total: 19.8s	remaining: 10.4s
# 164:	learn: 0.5047722	total: 19.9s	remaining: 10.2s
# 165:	learn: 0.5039257	total: 20s	remaining: 10.1s
# 166:	learn: 0.5031443	total: 20.1s	remaining: 9.97s
# 167:	learn: 0.5022998	total: 20.2s	remaining: 9.84s
# 168:	learn: 0.5015193	total: 20.2s	remaining: 9.69s
# 169:	learn: 0.5006842	total: 20.4s	remaining: 9.59s
# 170:	learn: 0.4998748	total: 20.5s	remaining: 9.45s
# 171:	learn: 0.4990783	total: 20.5s	remaining: 9.3s
# 172:	learn: 0.4982991	total: 20.6s	remaining: 9.16s
# 173:	learn: 0.4974955	total: 20.7s	remaining: 9.02s
# 174:	learn: 0.4967107	total: 20.7s	remaining: 8.89s
# 175:	learn: 0.4959175	total: 20.8s	remaining: 8.75s
# 176:	learn: 0.4951328	total: 20.9s	remaining: 8.61s
# 177:	learn: 0.4943653	total: 20.9s	remaining: 8.47s
# 178:	learn: 0.4936264	total: 21s	remaining: 8.33s
# 179:	learn: 0.4928383	total: 21.1s	remaining: 8.19s
# 180:	learn: 0.4920859	total: 21.1s	remaining: 8.05s
# 181:	learn: 0.4913340	total: 21.2s	remaining: 7.91s
# 182:	learn: 0.4905544	total: 21.3s	remaining: 7.79s
# 183:	learn: 0.4897735	total: 21.4s	remaining: 7.67s
# 184:	learn: 0.4890434	total: 21.4s	remaining: 7.52s
# 185:	learn: 0.4883028	total: 21.5s	remaining: 7.4s
# 186:	learn: 0.4875435	total: 21.6s	remaining: 7.27s
# 187:	learn: 0.4868321	total: 21.6s	remaining: 7.13s
# 188:	learn: 0.4860713	total: 21.7s	remaining: 7.01s
# 189:	learn: 0.4853506	total: 21.8s	remaining: 6.88s
# 190:	learn: 0.4846063	total: 21.8s	remaining: 6.75s
# 191:	learn: 0.4838444	total: 22s	remaining: 6.63s
# 192:	learn: 0.4830976	total: 22s	remaining: 6.51s
# 193:	learn: 0.4823669	total: 22.1s	remaining: 6.38s
# 194:	learn: 0.4816533	total: 22.2s	remaining: 6.25s
# 195:	learn: 0.4808967	total: 22.3s	remaining: 6.15s
# 196:	learn: 0.4801989	total: 22.4s	remaining: 6.01s
# 197:	learn: 0.4795011	total: 22.4s	remaining: 5.89s
# 198:	learn: 0.4787703	total: 22.5s	remaining: 5.77s
# 199:	learn: 0.4780520	total: 22.6s	remaining: 5.65s
# 200:	learn: 0.4773722	total: 22.6s	remaining: 5.52s
# 201:	learn: 0.4766488	total: 22.8s	remaining: 5.43s
# 202:	learn: 0.4759232	total: 23s	remaining: 5.32s
# 203:	learn: 0.4751882	total: 23.2s	remaining: 5.22s
# 204:	learn: 0.4745122	total: 23.2s	remaining: 5.09s
# 205:	learn: 0.4738272	total: 23.3s	remaining: 4.97s
# 206:	learn: 0.4731573	total: 23.3s	remaining: 4.84s
# 207:	learn: 0.4724731	total: 23.4s	remaining: 4.72s
# 208:	learn: 0.4717614	total: 23.5s	remaining: 4.62s
# 209:	learn: 0.4710497	total: 23.8s	remaining: 4.52s
# 210:	learn: 0.4703705	total: 23.8s	remaining: 4.4s
# 211:	learn: 0.4696560	total: 24.3s	remaining: 4.36s
# 212:	learn: 0.4689887	total: 24.4s	remaining: 4.23s
# 213:	learn: 0.4682851	total: 24.5s	remaining: 4.12s
# 214:	learn: 0.4676200	total: 24.6s	remaining: 4s
# 215:	learn: 0.4669344	total: 24.7s	remaining: 3.88s
# 216:	learn: 0.4662469	total: 24.8s	remaining: 3.77s
# 217:	learn: 0.4656010	total: 24.8s	remaining: 3.65s
# 218:	learn: 0.4649113	total: 25s	remaining: 3.54s
# 219:	learn: 0.4642454	total: 25.1s	remaining: 3.42s
# 220:	learn: 0.4635557	total: 25.6s	remaining: 3.35s
# 221:	learn: 0.4628837	total: 25.7s	remaining: 3.23s
# 222:	learn: 0.4622173	total: 25.8s	remaining: 3.13s
# 223:	learn: 0.4615701	total: 25.9s	remaining: 3s
# 224:	learn: 0.4609331	total: 25.9s	remaining: 2.88s
# 225:	learn: 0.4602790	total: 26s	remaining: 2.76s
# 226:	learn: 0.4596785	total: 26.1s	remaining: 2.64s
# 227:	learn: 0.4590551	total: 26.1s	remaining: 2.52s
# 228:	learn: 0.4584064	total: 26.2s	remaining: 2.4s
# 229:	learn: 0.4577785	total: 26.3s	remaining: 2.29s
# 230:	learn: 0.4571358	total: 26.4s	remaining: 2.17s
# 231:	learn: 0.4565200	total: 26.4s	remaining: 2.05s
# 232:	learn: 0.4558810	total: 26.5s	remaining: 1.94s
# 233:	learn: 0.4552618	total: 26.6s	remaining: 1.82s
# 234:	learn: 0.4545963	total: 28.4s	remaining: 1.81s
# 235:	learn: 0.4539507	total: 28.6s	remaining: 1.7s
# 236:	learn: 0.4533156	total: 28.8s	remaining: 1.58s
# 237:	learn: 0.4530123	total: 28.8s	remaining: 1.45s
# 238:	learn: 0.4523978	total: 28.9s	remaining: 1.33s
# 239:	learn: 0.4517825	total: 29s	remaining: 1.21s
# 240:	learn: 0.4511763	total: 29s	remaining: 1.08s
# 241:	learn: 0.4505595	total: 29.1s	remaining: 962ms
# 242:	learn: 0.4499393	total: 29.3s	remaining: 843ms
# 243:	learn: 0.4493580	total: 29.3s	remaining: 721ms
# 244:	learn: 0.4487519	total: 29.4s	remaining: 600ms
# 245:	learn: 0.4481885	total: 29.5s	remaining: 479ms
# 246:	learn: 0.4475806	total: 29.6s	remaining: 359ms
# 247:	learn: 0.4469912	total: 29.6s	remaining: 239ms
# 248:	learn: 0.4464345	total: 29.7s	remaining: 119ms
# 249:	learn: 0.4458732	total: 29.7s	remaining: 0us
# Fold Number 4/5
# 0:	learn: 0.6915959	total: 60.2ms	remaining: 15s
# 1:	learn: 0.6900949	total: 127ms	remaining: 15.7s
# 2:	learn: 0.6885543	total: 190ms	remaining: 15.6s
# 3:	learn: 0.6870633	total: 237ms	remaining: 14.6s
# 4:	learn: 0.6855071	total: 336ms	remaining: 16.5s
# 5:	learn: 0.6839877	total: 424ms	remaining: 17.3s
# 6:	learn: 0.6825222	total: 494ms	remaining: 17.2s
# 7:	learn: 0.6810015	total: 565ms	remaining: 17.1s
# 8:	learn: 0.6794651	total: 649ms	remaining: 17.4s
# 9:	learn: 0.6779210	total: 762ms	remaining: 18.3s
# 10:	learn: 0.6763646	total: 2.48s	remaining: 53.9s
# 11:	learn: 0.6748734	total: 2.54s	remaining: 50.4s
# 12:	learn: 0.6734188	total: 2.6s	remaining: 47.4s
# 13:	learn: 0.6719639	total: 2.67s	remaining: 45s
# 14:	learn: 0.6705415	total: 2.74s	remaining: 43s
# 15:	learn: 0.6690370	total: 2.83s	remaining: 41.4s
# 16:	learn: 0.6675628	total: 2.9s	remaining: 39.8s
# 17:	learn: 0.6660574	total: 3.04s	remaining: 39.1s
# 18:	learn: 0.6646089	total: 3.11s	remaining: 37.8s
# 19:	learn: 0.6631408	total: 3.19s	remaining: 36.6s
# 20:	learn: 0.6616826	total: 3.27s	remaining: 35.7s
# 21:	learn: 0.6602305	total: 3.38s	remaining: 35s
# 22:	learn: 0.6588050	total: 3.43s	remaining: 33.9s
# 23:	learn: 0.6573646	total: 3.5s	remaining: 33s
# 24:	learn: 0.6559111	total: 3.6s	remaining: 32.4s
# 25:	learn: 0.6544934	total: 3.69s	remaining: 31.8s
# 26:	learn: 0.6530832	total: 3.76s	remaining: 31s
# 27:	learn: 0.6516859	total: 3.81s	remaining: 30.2s
# 28:	learn: 0.6503226	total: 3.87s	remaining: 29.5s
# 29:	learn: 0.6489723	total: 3.93s	remaining: 28.8s
# 30:	learn: 0.6475510	total: 4.03s	remaining: 28.4s
# 31:	learn: 0.6461887	total: 4.09s	remaining: 27.9s
# 32:	learn: 0.6447947	total: 4.17s	remaining: 27.4s
# 33:	learn: 0.6434476	total: 4.25s	remaining: 27s
# 34:	learn: 0.6420638	total: 4.33s	remaining: 26.6s
# 35:	learn: 0.6407237	total: 4.38s	remaining: 26s
# 36:	learn: 0.6393947	total: 4.44s	remaining: 25.6s
# 37:	learn: 0.6380953	total: 4.5s	remaining: 25.1s
# 38:	learn: 0.6367221	total: 4.66s	remaining: 25.2s
# 39:	learn: 0.6354217	total: 4.71s	remaining: 24.8s
# 40:	learn: 0.6340964	total: 4.79s	remaining: 24.4s
# 41:	learn: 0.6327387	total: 4.9s	remaining: 24.3s
# 42:	learn: 0.6313760	total: 5.02s	remaining: 24.2s
# 43:	learn: 0.6300951	total: 5.08s	remaining: 23.8s
# 44:	learn: 0.6287784	total: 5.17s	remaining: 23.6s
# 45:	learn: 0.6275234	total: 5.22s	remaining: 23.2s
# 46:	learn: 0.6261880	total: 5.33s	remaining: 23s
# 47:	learn: 0.6249174	total: 5.41s	remaining: 22.8s
# 48:	learn: 0.6235979	total: 5.55s	remaining: 22.8s
# 49:	learn: 0.6223295	total: 5.64s	remaining: 22.6s
# 50:	learn: 0.6210557	total: 5.74s	remaining: 22.4s
# 51:	learn: 0.6197784	total: 5.91s	remaining: 22.5s
# 52:	learn: 0.6184390	total: 7.66s	remaining: 28.5s
# 53:	learn: 0.6172179	total: 7.71s	remaining: 28s
# 54:	learn: 0.6160042	total: 7.77s	remaining: 27.6s
# 55:	learn: 0.6147775	total: 7.83s	remaining: 27.1s
# 56:	learn: 0.6135192	total: 7.9s	remaining: 26.8s
# 57:	learn: 0.6122503	total: 7.98s	remaining: 26.4s
# 58:	learn: 0.6109851	total: 8.06s	remaining: 26.1s
# 59:	learn: 0.6097793	total: 8.11s	remaining: 25.7s
# 60:	learn: 0.6085838	total: 8.18s	remaining: 25.3s
# 61:	learn: 0.6073789	total: 8.23s	remaining: 24.9s
# 62:	learn: 0.6061633	total: 8.3s	remaining: 24.6s
# 63:	learn: 0.6049367	total: 8.37s	remaining: 24.3s
# 64:	learn: 0.6037429	total: 8.43s	remaining: 24s
# 65:	learn: 0.6025316	total: 8.48s	remaining: 23.7s
# 66:	learn: 0.6012885	total: 8.71s	remaining: 23.8s
# 67:	learn: 0.6001166	total: 8.76s	remaining: 23.4s
# 68:	learn: 0.5988596	total: 8.9s	remaining: 23.4s
# 69:	learn: 0.5976121	total: 10.7s	remaining: 27.5s
# 70:	learn: 0.5963850	total: 10.8s	remaining: 27.2s
# 71:	learn: 0.5952184	total: 10.8s	remaining: 26.8s
# 72:	learn: 0.5940619	total: 10.9s	remaining: 26.4s
# 73:	learn: 0.5929010	total: 11s	remaining: 26.1s
# 74:	learn: 0.5917671	total: 11s	remaining: 25.7s
# 75:	learn: 0.5906256	total: 11.1s	remaining: 25.3s
# 76:	learn: 0.5894615	total: 11.2s	remaining: 25.2s
# 77:	learn: 0.5882992	total: 11.3s	remaining: 24.8s
# 78:	learn: 0.5871415	total: 11.3s	remaining: 24.5s
# 79:	learn: 0.5860171	total: 11.4s	remaining: 24.2s
# 80:	learn: 0.5848721	total: 11.4s	remaining: 23.9s
# 81:	learn: 0.5837438	total: 11.5s	remaining: 23.6s
# 82:	learn: 0.5826590	total: 11.6s	remaining: 23.2s
# 83:	learn: 0.5814941	total: 11.6s	remaining: 23s
# 84:	learn: 0.5803320	total: 11.9s	remaining: 23s
# 85:	learn: 0.5792425	total: 11.9s	remaining: 22.7s
# 86:	learn: 0.5781245	total: 12s	remaining: 22.5s
# 87:	learn: 0.5770392	total: 12.1s	remaining: 22.2s
# 88:	learn: 0.5759204	total: 12.2s	remaining: 22s
# 89:	learn: 0.5747837	total: 12.3s	remaining: 21.9s
# 90:	learn: 0.5737209	total: 12.4s	remaining: 21.6s
# 91:	learn: 0.5726025	total: 12.5s	remaining: 21.4s
# 92:	learn: 0.5715045	total: 12.5s	remaining: 21.2s
# 93:	learn: 0.5704727	total: 12.6s	remaining: 20.9s
# 94:	learn: 0.5694101	total: 12.6s	remaining: 20.6s
# 95:	learn: 0.5683082	total: 12.7s	remaining: 20.4s
# 96:	learn: 0.5673001	total: 12.7s	remaining: 20.1s
# 97:	learn: 0.5662088	total: 12.8s	remaining: 19.9s
# 98:	learn: 0.5651965	total: 12.9s	remaining: 19.7s
# 99:	learn: 0.5641273	total: 13s	remaining: 19.4s
# 100:	learn: 0.5630230	total: 13.4s	remaining: 19.8s
# 101:	learn: 0.5619614	total: 13.5s	remaining: 19.6s
# 102:	learn: 0.5609117	total: 13.6s	remaining: 19.3s
# 103:	learn: 0.5599011	total: 13.6s	remaining: 19.1s
# 104:	learn: 0.5588501	total: 13.7s	remaining: 18.9s
# 105:	learn: 0.5577813	total: 13.8s	remaining: 18.7s
# 106:	learn: 0.5567677	total: 13.8s	remaining: 18.5s
# 107:	learn: 0.5557376	total: 13.9s	remaining: 18.3s
# 108:	learn: 0.5546826	total: 14s	remaining: 18.1s
# 109:	learn: 0.5536836	total: 14.1s	remaining: 17.9s
# 110:	learn: 0.5526573	total: 14.1s	remaining: 17.7s
# 111:	learn: 0.5516885	total: 14.2s	remaining: 17.5s
# 112:	learn: 0.5506620	total: 14.3s	remaining: 17.3s
# 113:	learn: 0.5496599	total: 14.3s	remaining: 17.1s
# 114:	learn: 0.5486696	total: 14.4s	remaining: 16.9s
# 115:	learn: 0.5476642	total: 14.4s	remaining: 16.7s
# 116:	learn: 0.5467158	total: 14.5s	remaining: 16.5s
# 117:	learn: 0.5457353	total: 14.6s	remaining: 16.3s
# 118:	learn: 0.5447535	total: 14.7s	remaining: 16.1s
# 119:	learn: 0.5437982	total: 14.7s	remaining: 15.9s
# 120:	learn: 0.5428033	total: 14.8s	remaining: 15.8s
# 121:	learn: 0.5418167	total: 14.9s	remaining: 15.6s
# 122:	learn: 0.5408476	total: 14.9s	remaining: 15.4s
# 123:	learn: 0.5399022	total: 15s	remaining: 15.2s
# 124:	learn: 0.5388953	total: 15.1s	remaining: 15.1s
# 125:	learn: 0.5379067	total: 15.2s	remaining: 15s
# 126:	learn: 0.5369060	total: 16.3s	remaining: 15.8s
# 127:	learn: 0.5359429	total: 16.4s	remaining: 15.6s
# 128:	learn: 0.5349559	total: 16.5s	remaining: 15.5s
# 129:	learn: 0.5340300	total: 16.6s	remaining: 15.3s
# 130:	learn: 0.5331027	total: 16.6s	remaining: 15.1s
# 131:	learn: 0.5321407	total: 16.7s	remaining: 15s
# 132:	learn: 0.5312017	total: 16.8s	remaining: 14.8s
# 133:	learn: 0.5302974	total: 16.9s	remaining: 14.6s
# 134:	learn: 0.5293592	total: 16.9s	remaining: 14.4s
# 135:	learn: 0.5284538	total: 17s	remaining: 14.3s
# 136:	learn: 0.5275588	total: 17.1s	remaining: 14.1s
# 137:	learn: 0.5266299	total: 17.2s	remaining: 13.9s
# 138:	learn: 0.5257155	total: 17.2s	remaining: 13.8s
# 139:	learn: 0.5248572	total: 17.3s	remaining: 13.6s
# 140:	learn: 0.5239717	total: 17.3s	remaining: 13.4s
# 141:	learn: 0.5230995	total: 17.4s	remaining: 13.2s
# 142:	learn: 0.5222434	total: 17.5s	remaining: 13.1s
# 143:	learn: 0.5213413	total: 17.5s	remaining: 12.9s
# 144:	learn: 0.5204709	total: 17.6s	remaining: 12.7s
# 145:	learn: 0.5195829	total: 17.7s	remaining: 12.6s
# 146:	learn: 0.5186970	total: 17.7s	remaining: 12.4s
# 147:	learn: 0.5177651	total: 18.8s	remaining: 13s
# 148:	learn: 0.5169123	total: 18.9s	remaining: 12.8s
# 149:	learn: 0.5160254	total: 19s	remaining: 12.6s
# 150:	learn: 0.5152026	total: 19s	remaining: 12.5s
# 151:	learn: 0.5143107	total: 19.1s	remaining: 12.3s
# 152:	learn: 0.5134432	total: 19.2s	remaining: 12.2s
# 153:	learn: 0.5125698	total: 19.3s	remaining: 12s
# 154:	learn: 0.5116857	total: 19.4s	remaining: 11.9s
# 155:	learn: 0.5108109	total: 19.5s	remaining: 11.7s
# 156:	learn: 0.5099621	total: 19.6s	remaining: 11.6s
# 157:	learn: 0.5091540	total: 19.6s	remaining: 11.4s
# 158:	learn: 0.5082751	total: 19.8s	remaining: 11.3s
# 159:	learn: 0.5074282	total: 19.9s	remaining: 11.2s
# 160:	learn: 0.5065523	total: 21.1s	remaining: 11.6s
# 161:	learn: 0.5057225	total: 21.1s	remaining: 11.5s
# 162:	learn: 0.5048834	total: 21.2s	remaining: 11.3s
# 163:	learn: 0.5040738	total: 21.3s	remaining: 11.2s
# 164:	learn: 0.5032806	total: 21.3s	remaining: 11s
# 165:	learn: 0.5024494	total: 21.4s	remaining: 10.8s
# 166:	learn: 0.5016325	total: 21.4s	remaining: 10.7s
# 167:	learn: 0.5008483	total: 21.5s	remaining: 10.5s
# 168:	learn: 0.5000644	total: 21.6s	remaining: 10.3s
# 169:	learn: 0.4992608	total: 21.6s	remaining: 10.2s
# 170:	learn: 0.4984261	total: 22.1s	remaining: 10.2s
# 171:	learn: 0.4976173	total: 22.3s	remaining: 10.1s
# 172:	learn: 0.4968199	total: 22.3s	remaining: 9.94s
# 173:	learn: 0.4960177	total: 22.4s	remaining: 9.79s
# 174:	learn: 0.4952491	total: 22.5s	remaining: 9.63s
# 175:	learn: 0.4944903	total: 22.5s	remaining: 9.47s
# 176:	learn: 0.4937061	total: 22.6s	remaining: 9.32s
# 177:	learn: 0.4929415	total: 22.7s	remaining: 9.17s
# 178:	learn: 0.4921861	total: 22.7s	remaining: 9.01s
# 179:	learn: 0.4914089	total: 22.8s	remaining: 8.86s
# 180:	learn: 0.4906058	total: 23s	remaining: 8.75s
# 181:	learn: 0.4898441	total: 23s	remaining: 8.6s
# 182:	learn: 0.4890715	total: 23.1s	remaining: 8.45s
# 183:	learn: 0.4883116	total: 23.1s	remaining: 8.29s
# ...
# 2:	learn: 0.6912206	total: 52.1ms	remaining: 1.69s
# 3:	learn: 0.6906659	total: 69ms	remaining: 1.66s
# 4:	learn: 0.6899858	total: 86.3ms	remaining: 1.64s
# 5:	learn: 0.6894309	total: 102ms	remaining: 1.6s
# 6:	learn: 0.6887897	total: 120ms	remaining: 1.59s
# 7:	learn: 0.6882101	total: 140ms	remaining: 1.61s
# 8:	learn: 0.6875738	total: 158ms	remaining: 1.6s
# 9:	learn: 0.6869163	total: 175ms	remaining: 1.57s
# 10:	learn: 0.6863574	total: 192ms	remaining: 1.56s
# 11:	learn: 0.6856962	total: 210ms	remaining: 1.54s
# 12:	learn: 0.6851417	total: 232ms	remaining: 1.55s
# 13:	learn: 0.6845799	total: 253ms	remaining: 1.55s
# 14:	learn: 0.6840244	total: 272ms	remaining: 1.54s
# 15:	learn: 0.6833622	total: 289ms	remaining: 1.51s
# 16:	learn: 0.6828064	total: 306ms	remaining: 1.49s
# 17:	learn: 0.6821574	total: 322ms	remaining: 1.47s
# 18:	learn: 0.6815294	total: 338ms	remaining: 1.44s
# 19:	learn: 0.6808713	total: 354ms	remaining: 1.42s
# 20:	learn: 0.6803400	total: 371ms	remaining: 1.39s
# 21:	learn: 0.6797027	total: 387ms	remaining: 1.37s
# 22:	learn: 0.6791279	total: 403ms	remaining: 1.35s
# 23:	learn: 0.6784956	total: 424ms	remaining: 1.34s
# 24:	learn: 0.6779154	total: 446ms	remaining: 1.34s
# 25:	learn: 0.6772701	total: 462ms	remaining: 1.31s
# 26:	learn: 0.6766960	total: 480ms	remaining: 1.3s
# 27:	learn: 0.6760626	total: 497ms	remaining: 1.28s
# 28:	learn: 0.6755087	total: 513ms	remaining: 1.26s
# 29:	learn: 0.6748769	total: 530ms	remaining: 1.24s
# 30:	learn: 0.6743212	total: 547ms	remaining: 1.22s
# 31:	learn: 0.6737866	total: 563ms	remaining: 1.2s
# 32:	learn: 0.6732129	total: 579ms	remaining: 1.18s
# 33:	learn: 0.6726060	total: 600ms	remaining: 1.16s
# 34:	learn: 0.6720385	total: 622ms	remaining: 1.15s
# 35:	learn: 0.6714082	total: 641ms	remaining: 1.14s
# 36:	learn: 0.6708494	total: 659ms	remaining: 1.12s
# 37:	learn: 0.6703005	total: 675ms	remaining: 1.1s
# 38:	learn: 0.6696710	total: 692ms	remaining: 1.08s
# 39:	learn: 0.6691210	total: 716ms	remaining: 1.07s
# 40:	learn: 0.6685872	total: 735ms	remaining: 1.06s
# 41:	learn: 0.6680139	total: 753ms	remaining: 1.04s
# 42:	learn: 0.6674098	total: 771ms	remaining: 1.02s
# 43:	learn: 0.6668370	total: 791ms	remaining: 1.01s
# 44:	learn: 0.6662131	total: 810ms	remaining: 990ms
# 45:	learn: 0.6656640	total: 829ms	remaining: 973ms
# 46:	learn: 0.6650410	total: 851ms	remaining: 960ms
# 47:	learn: 0.6645612	total: 870ms	remaining: 943ms
# 48:	learn: 0.6639400	total: 888ms	remaining: 924ms
# 49:	learn: 0.6634089	total: 914ms	remaining: 914ms
# 50:	learn: 0.6628765	total: 935ms	remaining: 898ms
# 51:	learn: 0.6623059	total: 955ms	remaining: 882ms
# 52:	learn: 0.6617039	total: 978ms	remaining: 867ms
# 53:	learn: 0.6612284	total: 997ms	remaining: 850ms
# 54:	learn: 0.6606083	total: 1.02s	remaining: 834ms
# 55:	learn: 0.6600651	total: 1.04s	remaining: 817ms
# 56:	learn: 0.6595089	total: 1.06s	remaining: 802ms
# 57:	learn: 0.6588900	total: 1.09s	remaining: 787ms
# 58:	learn: 0.6583398	total: 1.11s	remaining: 772ms
# 59:	learn: 0.6577972	total: 1.13s	remaining: 756ms
# 60:	learn: 0.6572666	total: 1.16s	remaining: 739ms
# 61:	learn: 0.6567109	total: 1.18s	remaining: 722ms
# 62:	learn: 0.6561648	total: 1.2s	remaining: 704ms
# 63:	learn: 0.6555702	total: 1.22s	remaining: 689ms
# 64:	learn: 0.6550956	total: 1.25s	remaining: 671ms
# 65:	learn: 0.6544978	total: 1.27s	remaining: 654ms
# 66:	learn: 0.6539257	total: 1.3s	remaining: 639ms
# 67:	learn: 0.6533494	total: 1.35s	remaining: 637ms
# 68:	learn: 0.6528765	total: 1.4s	remaining: 628ms
# 69:	learn: 0.6522655	total: 1.42s	remaining: 611ms
# 70:	learn: 0.6517184	total: 1.45s	remaining: 594ms
# 71:	learn: 0.6511886	total: 1.49s	remaining: 580ms
# 72:	learn: 0.6506421	total: 1.54s	remaining: 570ms
# 73:	learn: 0.6501244	total: 1.59s	remaining: 558ms
# 74:	learn: 0.6496545	total: 1.63s	remaining: 545ms
# 75:	learn: 0.6490385	total: 1.67s	remaining: 528ms
# 76:	learn: 0.6485152	total: 1.73s	remaining: 517ms
# 77:	learn: 0.6480034	total: 1.78s	remaining: 502ms
# 78:	learn: 0.6474572	total: 1.81s	remaining: 482ms
# 79:	learn: 0.6469412	total: 1.85s	remaining: 462ms
# 80:	learn: 0.6463949	total: 1.87s	remaining: 439ms
# 81:	learn: 0.6458818	total: 1.9s	remaining: 416ms
# 82:	learn: 0.6453389	total: 1.92s	remaining: 394ms
# 83:	learn: 0.6447494	total: 1.94s	remaining: 370ms
# 84:	learn: 0.6442776	total: 1.97s	remaining: 347ms
# 85:	learn: 0.6437569	total: 2s	remaining: 325ms
# 86:	learn: 0.6432071	total: 2.02s	remaining: 302ms
# 87:	learn: 0.6426801	total: 2.04s	remaining: 279ms
# 88:	learn: 0.6421726	total: 2.06s	remaining: 255ms
# 89:	learn: 0.6416465	total: 2.09s	remaining: 232ms
# 90:	learn: 0.6410188	total: 2.11s	remaining: 209ms
# 91:	learn: 0.6405929	total: 2.13s	remaining: 185ms
# 92:	learn: 0.6400644	total: 2.15s	remaining: 162ms
# 93:	learn: 0.6395944	total: 2.18s	remaining: 139ms
# 94:	learn: 0.6389928	total: 2.21s	remaining: 116ms
# 95:	learn: 0.6385669	total: 2.23s	remaining: 93ms
# 96:	learn: 0.6379739	total: 2.25s	remaining: 69.7ms
# 97:	learn: 0.6374337	total: 2.27s	remaining: 46.4ms
# 98:	learn: 0.6369297	total: 2.29s	remaining: 23.1ms
# 99:	learn: 0.6364573	total: 2.3s	remaining: 0us
# Fold Number 4/5
# 0:	learn: 0.6925319	total: 23ms	remaining: 2.27s
# 1:	learn: 0.6919777	total: 54.3ms	remaining: 2.66s
# 2:	learn: 0.6912217	total: 83ms	remaining: 2.69s
# 3:	learn: 0.6906671	total: 109ms	remaining: 2.61s
# 4:	learn: 0.6899869	total: 131ms	remaining: 2.48s
# 5:	learn: 0.6894329	total: 150ms	remaining: 2.35s
# 6:	learn: 0.6887902	total: 168ms	remaining: 2.23s
# 7:	learn: 0.6882106	total: 186ms	remaining: 2.14s
# 8:	learn: 0.6875748	total: 203ms	remaining: 2.06s
# 9:	learn: 0.6869189	total: 222ms	remaining: 2s
# 10:	learn: 0.6863603	total: 242ms	remaining: 1.95s
# 11:	learn: 0.6856992	total: 263ms	remaining: 1.93s
# 12:	learn: 0.6851267	total: 281ms	remaining: 1.88s
# 13:	learn: 0.6845836	total: 302ms	remaining: 1.86s
# 14:	learn: 0.6840285	total: 321ms	remaining: 1.82s
# 15:	learn: 0.6833649	total: 339ms	remaining: 1.78s
# 16:	learn: 0.6828109	total: 355ms	remaining: 1.74s
# 17:	learn: 0.6821622	total: 372ms	remaining: 1.69s
# 18:	learn: 0.6815344	total: 389ms	remaining: 1.66s
# 19:	learn: 0.6808768	total: 405ms	remaining: 1.62s
# 20:	learn: 0.6803452	total: 425ms	remaining: 1.6s
# 21:	learn: 0.6797081	total: 444ms	remaining: 1.57s
# 22:	learn: 0.6791330	total: 461ms	remaining: 1.54s
# 23:	learn: 0.6785017	total: 478ms	remaining: 1.51s
# 24:	learn: 0.6779034	total: 494ms	remaining: 1.48s
# 25:	learn: 0.6772765	total: 512ms	remaining: 1.46s
# 26:	learn: 0.6767015	total: 528ms	remaining: 1.43s
# 27:	learn: 0.6760712	total: 544ms	remaining: 1.4s
# 28:	learn: 0.6755104	total: 560ms	remaining: 1.37s
# 29:	learn: 0.6749077	total: 579ms	remaining: 1.35s
# 30:	learn: 0.6743283	total: 595ms	remaining: 1.32s
# 31:	learn: 0.6737920	total: 617ms	remaining: 1.31s
# 32:	learn: 0.6732210	total: 635ms	remaining: 1.29s
# 33:	learn: 0.6726143	total: 658ms	remaining: 1.28s
# 34:	learn: 0.6719659	total: 675ms	remaining: 1.25s
# 35:	learn: 0.6714167	total: 692ms	remaining: 1.23s
# 36:	learn: 0.6708601	total: 710ms	remaining: 1.21s
# 37:	learn: 0.6703096	total: 727ms	remaining: 1.19s
# 38:	learn: 0.6697019	total: 743ms	remaining: 1.16s
# 39:	learn: 0.6691287	total: 759ms	remaining: 1.14s
# 40:	learn: 0.6685965	total: 776ms	remaining: 1.12s
# 41:	learn: 0.6680247	total: 797ms	remaining: 1.1s
# 42:	learn: 0.6674193	total: 818ms	remaining: 1.08s
# 43:	learn: 0.6668535	total: 837ms	remaining: 1.06s
# 44:	learn: 0.6662242	total: 854ms	remaining: 1.04s
# 45:	learn: 0.6656516	total: 872ms	remaining: 1.02s
# 46:	learn: 0.6650481	total: 889ms	remaining: 1s
# 47:	learn: 0.6645732	total: 907ms	remaining: 983ms
# 48:	learn: 0.6639507	total: 923ms	remaining: 961ms
# 49:	learn: 0.6634209	total: 939ms	remaining: 939ms
# 50:	learn: 0.6627991	total: 956ms	remaining: 919ms
# 51:	learn: 0.6623162	total: 976ms	remaining: 901ms
# 52:	learn: 0.6617156	total: 996ms	remaining: 883ms
# 53:	learn: 0.6611426	total: 1.01s	remaining: 863ms
# 54:	learn: 0.6606252	total: 1.03s	remaining: 843ms
# 55:	learn: 0.6600728	total: 1.05s	remaining: 822ms
# 56:	learn: 0.6594514	total: 1.06s	remaining: 802ms
# 57:	learn: 0.6588813	total: 1.08s	remaining: 783ms
# 58:	learn: 0.6582845	total: 1.1s	remaining: 764ms
# 59:	learn: 0.6578060	total: 1.12s	remaining: 745ms
# 60:	learn: 0.6572787	total: 1.13s	remaining: 725ms
# 61:	learn: 0.6566594	total: 1.16s	remaining: 708ms
# 62:	learn: 0.6561738	total: 1.18s	remaining: 691ms
# 63:	learn: 0.6555810	total: 1.19s	remaining: 671ms
# 64:	learn: 0.6551067	total: 1.21s	remaining: 651ms
# 65:	learn: 0.6545128	total: 1.23s	remaining: 632ms
# 66:	learn: 0.6539400	total: 1.24s	remaining: 613ms
# 67:	learn: 0.6533278	total: 1.26s	remaining: 593ms
# 68:	learn: 0.6527803	total: 1.28s	remaining: 574ms
# 69:	learn: 0.6522815	total: 1.29s	remaining: 554ms
# 70:	learn: 0.6517336	total: 1.31s	remaining: 535ms
# 71:	learn: 0.6512020	total: 1.33s	remaining: 517ms
# 72:	learn: 0.6506586	total: 1.35s	remaining: 500ms
# 73:	learn: 0.6501416	total: 1.37s	remaining: 482ms
# 74:	learn: 0.6496135	total: 1.39s	remaining: 463ms
# 75:	learn: 0.6490732	total: 1.41s	remaining: 444ms
# 76:	learn: 0.6485261	total: 1.42s	remaining: 425ms
# 77:	learn: 0.6480111	total: 1.44s	remaining: 406ms
# 78:	learn: 0.6474759	total: 1.46s	remaining: 387ms
# 79:	learn: 0.6469420	total: 1.47s	remaining: 368ms
# 80:	learn: 0.6463943	total: 1.49s	remaining: 349ms
# 81:	learn: 0.6458989	total: 1.5s	remaining: 330ms
# 82:	learn: 0.6453527	total: 1.52s	remaining: 311ms
# 83:	learn: 0.6447489	total: 1.54s	remaining: 293ms
# 84:	learn: 0.6442029	total: 1.56s	remaining: 276ms
# 85:	learn: 0.6437510	total: 1.58s	remaining: 257ms
# 86:	learn: 0.6432212	total: 1.6s	remaining: 239ms
# 87:	learn: 0.6426992	total: 1.61s	remaining: 220ms
# 88:	learn: 0.6421690	total: 1.63s	remaining: 201ms
# 89:	learn: 0.6416660	total: 1.65s	remaining: 183ms
# 90:	learn: 0.6410338	total: 1.66s	remaining: 165ms
# 91:	learn: 0.6405118	total: 1.68s	remaining: 146ms
# 92:	learn: 0.6400064	total: 1.7s	remaining: 128ms
# 93:	learn: 0.6396085	total: 1.72s	remaining: 110ms
# 94:	learn: 0.6390268	total: 1.74s	remaining: 91.6ms
# 95:	learn: 0.6385629	total: 1.76s	remaining: 73.4ms
# 96:	learn: 0.6379752	total: 1.78s	remaining: 55ms
# 97:	learn: 0.6374489	total: 1.8s	remaining: 36.7ms
# 98:	learn: 0.6369448	total: 1.81s	remaining: 18.3ms
# 99:	learn: 0.6364070	total: 1.83s	remaining: 0us
# Fold Number 5/5
# 0:	learn: 0.6925318	total: 22.7ms	remaining: 2.24s
# 1:	learn: 0.6919775	total: 43.1ms	remaining: 2.11s
# 2:	learn: 0.6912210	total: 59.9ms	remaining: 1.94s
# 3:	learn: 0.6906661	total: 77.2ms	remaining: 1.85s
# 4:	learn: 0.6899859	total: 93.7ms	remaining: 1.78s
# 5:	learn: 0.6894313	total: 110ms	remaining: 1.72s
# 6:	learn: 0.6887891	total: 126ms	remaining: 1.67s
# 7:	learn: 0.6882106	total: 142ms	remaining: 1.63s
# 8:	learn: 0.6875744	total: 161ms	remaining: 1.62s
# 9:	learn: 0.6869169	total: 178ms	remaining: 1.6s
# 10:	learn: 0.6863582	total: 196ms	remaining: 1.58s
# 11:	learn: 0.6856970	total: 212ms	remaining: 1.55s
# 12:	learn: 0.6851425	total: 231ms	remaining: 1.54s
# 13:	learn: 0.6845809	total: 251ms	remaining: 1.54s
# 14:	learn: 0.6840254	total: 270ms	remaining: 1.53s
# 15:	learn: 0.6833631	total: 289ms	remaining: 1.51s
# 16:	learn: 0.6828086	total: 305ms	remaining: 1.49s
# 17:	learn: 0.6821586	total: 321ms	remaining: 1.46s
# 18:	learn: 0.6815304	total: 337ms	remaining: 1.44s
# 19:	learn: 0.6808727	total: 353ms	remaining: 1.41s
# 20:	learn: 0.6803413	total: 371ms	remaining: 1.4s
# 21:	learn: 0.6797036	total: 389ms	remaining: 1.38s
# 22:	learn: 0.6791293	total: 405ms	remaining: 1.36s
# 23:	learn: 0.6784973	total: 426ms	remaining: 1.35s
# 24:	learn: 0.6778982	total: 446ms	remaining: 1.34s
# 25:	learn: 0.6772716	total: 464ms	remaining: 1.32s
# 26:	learn: 0.6766965	total: 482ms	remaining: 1.3s
# 27:	learn: 0.6760660	total: 498ms	remaining: 1.28s
# 28:	learn: 0.6755104	total: 515ms	remaining: 1.26s
# 29:	learn: 0.6749020	total: 531ms	remaining: 1.24s
# 30:	learn: 0.6743229	total: 548ms	remaining: 1.22s
# 31:	learn: 0.6737872	total: 564ms	remaining: 1.2s
# 32:	learn: 0.6732148	total: 581ms	remaining: 1.18s
# 33:	learn: 0.6726076	total: 602ms	remaining: 1.17s
# 34:	learn: 0.6720404	total: 623ms	remaining: 1.16s
# 35:	learn: 0.6714103	total: 640ms	remaining: 1.14s
# 36:	learn: 0.6708533	total: 656ms	remaining: 1.12s
# 37:	learn: 0.6703030	total: 674ms	remaining: 1.1s
# 38:	learn: 0.6696736	total: 693ms	remaining: 1.08s
# 39:	learn: 0.6691235	total: 711ms	remaining: 1.07s
# 40:	learn: 0.6685900	total: 729ms	remaining: 1.05s
# 41:	learn: 0.6680180	total: 747ms	remaining: 1.03s
# 42:	learn: 0.6674123	total: 766ms	remaining: 1.01s
# 43:	learn: 0.6668394	total: 786ms	remaining: 1s
# 44:	learn: 0.6662162	total: 809ms	remaining: 989ms
# 45:	learn: 0.6656672	total: 830ms	remaining: 974ms
# 46:	learn: 0.6650436	total: 847ms	remaining: 955ms
# 47:	learn: 0.6645639	total: 865ms	remaining: 937ms
# 48:	learn: 0.6639430	total: 883ms	remaining: 919ms
# 49:	learn: 0.6634117	total: 900ms	remaining: 900ms
# 50:	learn: 0.6628798	total: 918ms	remaining: 882ms
# 51:	learn: 0.6623065	total: 935ms	remaining: 863ms
# 52:	learn: 0.6617059	total: 955ms	remaining: 847ms
# 53:	learn: 0.6612316	total: 974ms	remaining: 830ms
# 54:	learn: 0.6606115	total: 995ms	remaining: 814ms
# 55:	learn: 0.6600675	total: 1.01s	remaining: 797ms
# 56:	learn: 0.6594408	total: 1.03s	remaining: 779ms
# 57:	learn: 0.6588690	total: 1.06s	remaining: 766ms
# 58:	learn: 0.6583428	total: 1.07s	remaining: 747ms
# 59:	learn: 0.6577948	total: 1.09s	remaining: 729ms
# 60:	learn: 0.6572685	total: 1.11s	remaining: 710ms
# 61:	learn: 0.6567359	total: 1.13s	remaining: 691ms
# 62:	learn: 0.6561636	total: 1.16s	remaining: 678ms
# 63:	learn: 0.6555725	total: 1.17s	remaining: 661ms
# 64:	learn: 0.6551007	total: 1.2s	remaining: 644ms
# 65:	learn: 0.6545018	total: 1.22s	remaining: 627ms
# 66:	learn: 0.6539280	total: 1.24s	remaining: 608ms
# 67:	learn: 0.6533530	total: 1.25s	remaining: 590ms
# 68:	learn: 0.6528865	total: 1.27s	remaining: 571ms
# 69:	learn: 0.6522695	total: 1.29s	remaining: 552ms
# 70:	learn: 0.6517222	total: 1.31s	remaining: 534ms
# 71:	learn: 0.6511929	total: 1.32s	remaining: 515ms
# 72:	learn: 0.6506452	total: 1.34s	remaining: 496ms
# 73:	learn: 0.6501285	total: 1.36s	remaining: 478ms
# 74:	learn: 0.6496583	total: 1.38s	remaining: 460ms
# 75:	learn: 0.6490412	total: 1.4s	remaining: 441ms
# 76:	learn: 0.6485192	total: 1.41s	remaining: 422ms
# 77:	learn: 0.6480073	total: 1.43s	remaining: 403ms
# 78:	learn: 0.6474616	total: 1.45s	remaining: 385ms
# 79:	learn: 0.6469265	total: 1.46s	remaining: 366ms
# 80:	learn: 0.6463995	total: 1.48s	remaining: 347ms
# 81:	learn: 0.6458865	total: 1.5s	remaining: 328ms
# 82:	learn: 0.6453436	total: 1.51s	remaining: 310ms
# 83:	learn: 0.6447292	total: 1.53s	remaining: 291ms
# 84:	learn: 0.6442823	total: 1.55s	remaining: 273ms
# 85:	learn: 0.6437606	total: 1.57s	remaining: 255ms
# 86:	learn: 0.6432072	total: 1.58s	remaining: 237ms
# 87:	learn: 0.6426840	total: 1.6s	remaining: 218ms
# 88:	learn: 0.6421578	total: 1.62s	remaining: 200ms
# 89:	learn: 0.6416503	total: 1.63s	remaining: 181ms
# 90:	learn: 0.6410193	total: 1.65s	remaining: 163ms
# 91:	learn: 0.6405964	total: 1.67s	remaining: 145ms
# 92:	learn: 0.6399915	total: 1.68s	remaining: 127ms
# 93:	learn: 0.6395984	total: 1.7s	remaining: 109ms
# 94:	learn: 0.6389983	total: 1.72s	remaining: 90.7ms
# 95:	learn: 0.6385467	total: 1.74s	remaining: 72.6ms
# 96:	learn: 0.6379777	total: 1.76s	remaining: 54.4ms
# 97:	learn: 0.6374391	total: 1.77s	remaining: 36.2ms
# 98:	learn: 0.6369342	total: 1.79s	remaining: 18.1ms
# 99:	learn: 0.6364624	total: 1.81s	remaining: 0us
#     ROC AUC  Precision@K Mean  Recall@K Mean  F1_Score          Model Name
# 0  0.844608          0.421789       0.812750     0.555  CatBoostClassifier
# 0  0.844329          0.416792       0.811683     0.551  CatBoostClassifier
# 0  0.841803          0.414793       0.806482     0.548  CatBoostClassifier
# 0  0.838544          0.386807       0.800747     0.522  CatBoostClassifier
# 0  0.836299          0.401799       0.785943     0.532  CatBoostClassifier
# 0  0.836059          0.399800       0.782875     0.529  CatBoostClassifier
# 0  0.834455          0.395802       0.782075     0.526  CatBoostClassifier
# 0  0.811848          0.271864       0.748600     0.399  CatBoostClassifier
# 0  0.769638          0.246877       0.637103     0.356  CatBoostClassifier
# 0  0.769638          0.246877       0.637103     0.356  CatBoostClassifier

# %% [markdown]
# ## Final Model
# **The best parameters are the standard used by the Classifier**

# %%
#define model
catboost_tuned = CatBoostClassifier(verbose = False, random_state = 22)

#train model
catboost_tuned = catboost_tuned.fit( x_train, y_train)

#model prediction
yhat_catboost_tuned = catboost_tuned.predict_proba( x_val)

# %%
accuracy_catboost_tuned = cross_validation(catboost_tuned, x_train, y_train, 5, df6, Verbose = False)
accuracy_catboost_tuned
# Out:
#            Model Name   ROC AUC  Precision@K Mean  Recall@K Mean  F1_Score
# 0  CatBoostClassifier  0.844092            0.4008       0.813284     0.537

# %% [markdown]
# # Performance Evaluation and Interpretation

# %% [markdown]
# ## Key findings on interested customers most relevant attributes

# %% [markdown]
# ### Insight #1:

# %% [markdown]
# ### Insight #2:

# %% [markdown]
# ### Insight #3:

# %% [markdown]
# ## What percentage of interested customers the sales team will be able to contact making 20.000 calls?

# %%
# Define dataset to apply final model
df9 = x_val.copy()
df9['response'] = y_val.copy()
df9['score'] = yhat_catboost_tuned[:, 1].tolist()
df9 = df9.sort_values('score', ascending=False)

# Define dataset percentage that defines 20.000 calls
percent = round((20000/len(df9)*100), 2)
# Apply Recall metric to define the percentage of interested customers was achieved by phone calling 20.000 people
recall_at_20000 = round((recall_at_k(df9))*100 , 2 )

print(f'Using {percent}% of the test data, the model could find {recall_at_20000}% of the total customers interested in purchase a car insurance.')
# Out:
# Using 26.24% of the test data, the model could find 69.37% of the total customers interested in purchase a car insurance.

# %%
fig, ax = plt.subplots(figsize = (25, 10))

plt.subplot(1, 2, 1)
plot_cumulative_gain(y_val, yhat_catboost_tuned[:,1])
plt.axvline(2.624, color ='#FF7F0E', ls = '--')
plt.title('Cumulative Gain Final Model - 20.000 calls')
plt.yticks(np.arange(0, 100, step = 10))
plt.xticks(np.arange(0, 10.5, step = 0.5))
plt.legend(['Final Model - Catboost Classifier', 'Wizard', 'Random', 'Test Percentage'])

bbox = dict(boxstyle ='round', fc ='0.7')
arrowprops = dict(facecolor ='#4D4D4D')
plt.annotate('Final Model: 69.37%', xy = (2.624, 69.37),
                xytext =(3, 67), 
                arrowprops = arrowprops, bbox = bbox)

plt.annotate('Random: ~26%', xy = (2.624, 26.24),
                xytext =(2.8, 29), 
                arrowprops = arrowprops, bbox = bbox);



plt.subplot(1, 2, 2)
plot_lift(y_val, yhat_catboost_tuned[:,1])
plt.axvline(2.624, color ='#FF7F0E', ls = '--')
plt.title('Lift Curve - 20.000 calls')
plt.yticks(np.arange(0, 3, step = 0.2))
plt.xticks(np.arange(0, 10.5, step = 0.5))
plt.legend(['Final Model - Catboost Classifier', 'Random', 'Test Percentage']);

# %% [markdown]
# ## By increasing the capacity to 40,000 calls, what percentage of interested customers the sales team will be able to contact?

# %%
# Define dataset percentage that defines 40.000 calls
percent = round((40000/len(df9)*100), 2)
# Apply Recall metric to define the percentage of interested customers was achieved by phone calling 20.000 people
recall_at_40000 = round((recall_at_k(df9, 40000))*100 , 2 )

print(f'Using {percent}% of the test data, the model could find {recall_at_40000}% of the total customers interested in purchase a car insurance.')
# Out:
# Using 52.48% of the test data, the model could find 98.67% of the total customers interested in purchase a car insurance.

# %%
fig, ax = plt.subplots(figsize = (25, 10))

plt.subplot(1, 2, 1)
plot_cumulative_gain(y_val, yhat_catboost_tuned[:,1])
plt.axvline(5.248, color ='#FF7F0E', ls = '--')
plt.title('Cumulative Gain Final Model - 40.000 calls')
plt.yticks(np.arange(0, 100, step = 10))
plt.xticks(np.arange(0, 10.5, step = 0.5))
plt.legend(['Final Model - Catboost Classifier', 'Wizard', 'Random', 'Test Percentage'])

arrowprops = dict(facecolor ='#4D4D4D')
plt.annotate('Final Model: 98.67%', xy = (5.248, 98.67),
                xytext =(5.7, 94), 
                arrowprops = arrowprops, bbox = bbox)

plt.annotate('Random: ~52%', xy = (5.248, 52.48),
                xytext =(5.7, 49), 
                arrowprops = arrowprops, bbox = bbox);



plt.subplot(1, 2, 2)
plot_lift(y_val, yhat_catboost_tuned[:,1])
plt.axvline(5.248, color ='#FF7F0E', ls = '--')
plt.title('Lift Curve - 40.000 calls')
plt.yticks(np.arange(0, 3, step = 0.2))
plt.xticks(np.arange(0, 10.5, step = 0.5))
plt.legend(['Final Model - Catboost Classifier', 'Random', 'Test Percentage']);
